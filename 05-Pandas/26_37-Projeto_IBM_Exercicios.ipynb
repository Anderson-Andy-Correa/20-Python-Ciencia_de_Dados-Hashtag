# %% [markdown]
# ## O dataset
#
# O dataset a ser utilizado é o *IBM HR Analytics Employee Attrition & Performance*, disponível no Kaggle. O dataset contém informações sobre funcionários de uma empresa fictícia, como idade, gênero, estado civil, nível de satisfação, entre outros. O objetivo é prever a probabilidade de um funcionário sair da empresa.
#
# [Link do Kaggle](https://www.kaggle.com/datasets/pavansubhasht/ibm-hr-analytics-attrition-dataset/data)
#
# Os termos *attrition* ("atrito") e *turnover* ("rotatividade") são frequentemente usados de forma intercambiável no contexto de recursos humanos e gestão de força de trabalho, mas eles se referem a conceitos ligeiramente diferentes em relação às mudanças no número e na composição dos empregados dentro de uma organização. Compreender a distinção entre esses dois é importante para analisar e relatar com precisão a dinâmica da força de trabalho.
#
# ### Atrito
#
# Atrito refere-se à redução gradual de empregados por meio de circunstâncias naturais, como aposentadoria, demissão voluntária por motivos pessoais, ou a decisão de não substituir empregados que estão de saída. Atrito pode levar a uma diminuição no tamanho da força de trabalho, mas é caracterizado por sua natureza voluntária e muitas vezes incontrolável. Organizações podem permitir o atrito para reduzir o tamanho de sua força de trabalho sem recorrer a demissões, vendo isso como uma forma menos disruptiva de ajustar seus níveis de pessoal.
#
# Em análises, quando você está analisando um conjunto de dados para atrito, você frequentemente olha para as razões por trás das saídas voluntárias e a taxa na qual estas ocorrem naturalmente ao longo do tempo. Taxas de atrito podem fornecer insights sobre a satisfação dos empregados e tendências de longo prazo da força de trabalho.
#
# ### Rotatividade
#
# Rotatividade, por outro lado, engloba um escopo mais amplo de partidas de empregados, incluindo tanto renúncias voluntárias quanto demissões involuntárias (como demissões ou términos por justa causa). Porém, ocorre a substituição da força de trabalho. Rotatividade é uma medida de quantos empregados estão deixando a companhia por qualquer motivo. Uma alta taxa de rotatividade pode indicar problemas com satisfação no trabalho, cultura do local de trabalho, ou estabilidade organizacional, e frequentemente requer ação da gestão para endereçar as causas subjacentes.
#
# Rotatividade é calculada dividindo o número de empregados que saem pelo número médio de empregados, geralmente em uma base anual, e expressando isso como uma porcentagem. Esta métrica é crucial para entender como as saídas de empregados, tanto voluntárias quanto involuntárias, afetam a capacidade da organização de manter uma força de trabalho estável e eficaz.
#
# ### Diferenças Chave
#
# - **Natureza**: Atrito geralmente é voluntário e pode ser devido a fatores naturais ou incontroláveis, enquanto rotatividade inclui tanto saídas voluntárias quanto demissões involuntárias.
# - **Implicações para Gestão**: Atrito pode ser parte de uma estratégia de ajuste natural da força de trabalho e nem sempre é negativo, enquanto alta rotatividade é frequentemente um sinal de problemas dentro da organização que precisam ser abordados.
# - **Foco Estratégico**: Análise de atrito pode focar em entender tendências de longo prazo da força de trabalho e planejamento de aposentadoria, enquanto análise de rotatividade é frequentemente usada para identificar questões imediatas com satisfação de empregados, engajamento, ou práticas de gestão que podem estar impactando a retenção de staff.
#
# Enquanto ambos atrito e rotatividade lidam com empregados deixando a organização, eles diferem em seu escopo e as implicações estratégicas para gerenciar e entender a dinâmica da força de trabalho. No seu conjunto de dados de empregados, distinguir entre atrito e rotatividade pode ajudar na customização de estratégias para planejamento da força de trabalho, retenção e desenvolvimento organizacional.

# %% [markdown]
# |    | Name                       | Description                                                                                                                                                    |
# |---:|:---------------------------|:---------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |  0 | Age                        | Numerical Value                                                                                                                                                |
# |  1 | Attrition                  | Employee leaving the company - Text - No, Yes                                                                                                                     |
# |  2 | BusinessTravel            | Text - Non-Travel, Travel_Frequently, Travel_Rarely                                                                                                             |
# |  3 | DailyRate                 | Numerical Value - Salary Level                                                                                                                                 |
# |  4 | Department                 | Text - Sales, Research & Development, Human Resources                                                                                                         |
# |  5 | DistanceFromHome         | Numerical Value - the distance from work to home in miles
# |  6 | Education                  | Numerical Value - 1=Below college, 2=College, 3=Bachelor, 4=Master, 5=PhD   |
# |  7 | EducationField            | Text - Life Sciences, Medical, Marketing, Techincal Degree, Human Resources, Other                                                                                   |
# |  8 | EmployeeCount             | Numerical Value - 1                                                                                                                                               |
# |  9 | EmployeeNumber            | Numerical Value - Employee ID                                                                                                                                  |
# | 10 | EnvironmentSatisfaction    | Numerical Value - 1=Low, 2=Medium, 3=High, 4=Very High |
# | 11 | Gender                     | Text - Female, Male                                                                                                                                             |
# | 12 | HourlyRate                | Numerical Value - Hourly Salary                                                                                                                                |
# | 13 | JobInvolvement            | Numerical Value - 1=Low, 2=Medium, 3=High, 4=Very High                                                                                                         |
# | 14 | JobLevel                  | Numerical Value - 1, 2, 3, 4, 5. Means different job levels                                                                                                     |
# | 15 | JobRole                   | Text - Sales Executive, Research Scientist, Laboratory Technician, Manufacturing Director, Healthcare Representative, Manager, Sales Representative, Research Director, Human Resources |
# | 16 | JobSatisfaction           | Numerical Value - 1=Low, 2=Medium, 3=High, 4=Very High                                                                                                         |
# | 17 | MaritalStatus             | Text - Single, Married, Divorced                                                                                                                                      |
# | 18 | MonthlyIncome             | Numerical Value - Monthly Salary                                                                                                                               |
# | 19 | MonthlyRate                | Numerical Value - Monthly Rate                                                                                                                                  |
# | 20 | NumCompaniesWorked        | Numerical Value - Number of companies worked at                                                                                                                |
# | 21 | Over18                    | Text - Y                                                                                                                                                    |
# | 22 | Overtime                   | Text - No, Yes                                                                                                                                                    |
# | 23 | PercentSalaryHike        | Numerical Value - Percentage increase in salary                                                                                                                |
# | 24 | PerformanceRating         | Numerical Value - 1=Low, 2=Good, 3=Excellent, 4=Outstanding                                                                                                    |
# | 25 | RelationshipSatisfaction  | Numerical Value - 1=Low, 2=Medium, 3=High, 4=Very High                                                                                                         |
# | 26 | StandardHours             | Numerical Value - 80                                                                                                                                            |
# | 27 | StockOptionsLevel        | Numerical Value - 0, 1, 2, 3                                                                                                                                    |
# | 28 | TotalWorkingYears        | Numerical Value - Total years worked                                                                                                                            |
# | 29 | TrainingTimesLastYear   | Numerical Value - How many times the employee has been trained last year                                                                                       |
# | 30 | WorkLifeBalance          | Numerical Value - 1=Bad, 2=Good, 3=Better, 4=Best                                                                                                              |
# | 31 | YearsAtCompany           | Numerical Value - Number of years at the company                                                                                                                |
# | 32 | YearsInCurrentRole      | Numerical Value -Number of years in current role                                                                                                                |
# | 33 | YearsSinceLastPromotion | Numerical Value - Years since last promotion                                                                                                                    |
# | 34 | YearsWithCurrManager | Numerical Value - Years with current manager                                                                                                                    |

# %%
import pandas as pd

DADOS = r".\Dados\employee_attrition.csv"

df = pd.read_csv(DADOS)

display(df)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 1                    8          1  Life Sciences              1
# 2                    2          2          Other              1
# 3                    3          4  Life Sciences              1
# 4                    2          1        Medical              1
# ...                ...        ...            ...            ...
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0                  1  ...                         1            80
# 1                  2  ...                         4            80
# 2                  4  ...                         2            80
# 3                  5  ...                         3            80
# 4                  7  ...                         4            80
# ...              ...  ...                       ...           ...
# 1465            2061  ...                         3            80
# 1466            2062  ...                         1            80
# 1467            2064  ...                         2            80
# 1468            2065  ...                         4            80
# 1469            2068  ...                         1            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                    0                  8                      0
# 1                    1                 10                      3
# 2                    0                  7                      3
# 3                    0                  8                      3
# 4                    1                  6                      3
# ...                ...                ...                    ...
# 1465                 1                 17                      3
# 1466                 1                  9                      5
# 1467                 1                  6                      0
# 1468                 0                 17                      3
# 1469                 0                  6                      3
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 0                  1               6                  4
# 1                  3              10                  7
# 2                  3               0                  0
# 3                  3               8                  7
# 4                  3               2                  2
# ...              ...             ...                ...
# 1465               3               5                  2
# 1466               3               7                  7
# 1467               3               6                  2
# 1468               2               9                  6
# 1469               4               4                  3
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                           0                     5
# 1                           1                     7
# 2                           0                     0
# 3                           3                     0
# 4                           2                     2
# ...                       ...                   ...
# 1465                        0                     3
# 1466                        1                     7
# 1467                        0                     3
# 1468                        0                     8
# 1469                        1                     2
#
# [1470 rows x 35 columns]

# %% [markdown]
# ## Exercícios
#
# - remover colunas com valores únicos
# - encontrar os registros dos 10 funcionários mais velhos e dos 10 mais novos
# - encontrar os registros dos 10 funcionários com mais tempo de empresa e dos 10 com menos tempo
# - encontrar os registros dos 10 funcionários com mais tempo no cargo (sem promoção) e dos 10 com menos tempo
# - agrupamentos (em cada caso, mostrar também o agrupamento por saída ou não do funcionário)
#   - contagem de funcionários por departamento
#   - média de salário por departamento
#   - gênero por departamento
#   - gênero por cargo
#   - média de salário por cargo
#   - média de salário por cargo e nível
#   - média de salário por nível educacional

# %% [markdown]
# * Remover colunas com valores únicos

# %%
# Remoção da coluna EmployeeNumber por conta de não agregar à análise da base de dados
remove_single_value_columns = [column for column, value in df.nunique().items() if value == 1]
df_colunas_removidas = df.drop(columns=remove_single_value_columns + ["EmployeeNumber"])
display(df_colunas_removidas)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                    1          2  Life Sciences                        2
# 1                    8          1  Life Sciences                        3
# 2                    2          2          Other                        4
# 3                    3          4  Life Sciences                        4
# 4                    2          1        Medical                        1
# ...                ...        ...            ...                      ...
# 1465                23          2        Medical                        3
# 1466                 6          1        Medical                        4
# 1467                 4          3  Life Sciences                        2
# 1468                 2          3        Medical                        4
# 1469                 8          3        Medical                        2
#
#       Gender  ...  PerformanceRating  RelationshipSatisfaction  \
# 0     Female  ...                  3                         1
# 1       Male  ...                  4                         4
# 2       Male  ...                  3                         2
# 3     Female  ...                  3                         3
# 4       Male  ...                  3                         4
# ...      ...  ...                ...                       ...
# 1465    Male  ...                  3                         3
# 1466    Male  ...                  3                         1
# 1467    Male  ...                  4                         2
# 1468    Male  ...                  3                         4
# 1469    Male  ...                  3                         1
#
#       StockOptionLevel TotalWorkingYears  TrainingTimesLastYear  \
# 0                    0                 8                      0
# 1                    1                10                      3
# 2                    0                 7                      3
# 3                    0                 8                      3
# 4                    1                 6                      3
# ...                ...               ...                    ...
# 1465                 1                17                      3
# 1466                 1                 9                      5
# 1467                 1                 6                      0
# 1468                 0                17                      3
# 1469                 0                 6                      3
#
#      WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                  1               6                   4
# 1                  3              10                   7
# 2                  3               0                   0
# 3                  3               8                   7
# 4                  3               2                   2
# ...              ...             ...                 ...
# 1465               3               5                   2
# 1466               3               7                   7
# 1467               3               6                   2
# 1468               2               9                   6
# 1469               4               4                   3
#
#       YearsSinceLastPromotion YearsWithCurrManager
# 0                           0                    5
# 1                           1                    7
# 2                           0                    0
# 3                           3                    0
# 4                           2                    2
# ...                       ...                  ...
# 1465                        0                    3
# 1466                        1                    7
# 1467                        0                    3
# 1468                        0                    8
# 1469                        1                    2
#
# [1470 rows x 31 columns]

# %% [markdown]
# * Encontrar os registros dos 10 funcionários mais velhos e dos 10 mais novos

# %% [markdown]
# ### Juntando os dados em um só DataFrame usando sort

# %%
df_funcionarios_mais_novos_e_mais_velhos = pd.concat(
    [df_colunas_removidas.sort_values(by="Age").head(10),
     df_colunas_removidas.sort_values(by="Age").tail(10)]
    )
display(df_funcionarios_mais_novos_e_mais_velhos)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 457    18       Yes  Travel_Frequently       1306                   Sales
# 828    18       Yes         Non-Travel        247  Research & Development
# 1153   18       Yes  Travel_Frequently        544                   Sales
# 1311   18        No         Non-Travel       1431  Research & Development
# 301    18        No      Travel_Rarely        812                   Sales
# 972    18        No         Non-Travel       1124  Research & Development
# 727    18        No         Non-Travel        287  Research & Development
# 296    18       Yes      Travel_Rarely        230  Research & Development
# 127    19       Yes      Travel_Rarely        528                   Sales
# 177    19       Yes      Travel_Rarely        303  Research & Development
# 232    59        No      Travel_Rarely        818         Human Resources
# 6      59        No      Travel_Rarely       1324  Research & Development
# 919    59        No      Travel_Rarely       1429  Research & Development
# 743    59        No      Travel_Rarely        715  Research & Development
# 225    59        No      Travel_Rarely        142  Research & Development
# 427    60        No  Travel_Frequently       1499                   Sales
# 411    60        No      Travel_Rarely        422  Research & Development
# 536    60        No      Travel_Rarely       1179                   Sales
# 879    60        No      Travel_Rarely        696                   Sales
# 1209   60        No      Travel_Rarely        370  Research & Development
#
#       DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 457                  5          3      Marketing                        2
# 828                  8          1        Medical                        3
# 1153                 3          2        Medical                        2
# 1311                14          3        Medical                        2
# 301                 10          3        Medical                        4
# 972                  1          3  Life Sciences                        4
# 727                  5          2  Life Sciences                        2
# 296                  3          3  Life Sciences                        3
# 127                 22          1      Marketing                        4
# 177                  2          3  Life Sciences                        2
# 232                  6          2        Medical                        2
# 6                    3          3        Medical                        3
# 919                 18          4        Medical                        4
# 743                  2          3  Life Sciences                        3
# 225                  3          3  Life Sciences                        3
# 427                 28          3      Marketing                        3
# 411                  7          3  Life Sciences                        1
# 536                 16          4      Marketing                        1
# 879                  7          4      Marketing                        2
# 1209                 1          4        Medical                        3
#
#       Gender  ...  PerformanceRating  RelationshipSatisfaction  \
# 457     Male  ...                  3                         4
# 828     Male  ...                  3                         4
# 1153  Female  ...                  3                         3
# 1311  Female  ...                  3                         3
# 301   Female  ...                  3                         1
# 972   Female  ...                  3                         3
# 727     Male  ...                  3                         4
# 296     Male  ...                  3                         3
# 127     Male  ...                  3                         4
# 177     Male  ...                  4                         3
# 232     Male  ...                  3                         4
# 6     Female  ...                  4                         1
# 919     Male  ...                  3                         4
# 743   Female  ...                  3                         1
# 225     Male  ...                  3                         1
# 427   Female  ...                  3                         4
# 411   Female  ...                  3                         4
# 536     Male  ...                  3                         4
# 879     Male  ...                  3                         2
# 1209    Male  ...                  4                         3
#
#       StockOptionLevel TotalWorkingYears  TrainingTimesLastYear  \
# 457                  0                 0                      3
# 828                  0                 0                      0
# 1153                 0                 0                      2
# 1311                 0                 0                      4
# 301                  0                 0                      2
# 972                  0                 0                      5
# 727                  0                 0                      2
# 296                  0                 0                      2
# 127                  0                 0                      2
# 177                  0                 1                      3
# 232                  0                 7                      2
# 6                    3                12                      3
# 919                  0                25                      6
# 743                  0                30                      4
# 225                  1                 7                      6
# 427                  0                22                      5
# 411                  0                33                      5
# 536                  0                10                      1
# 879                  1                12                      3
# 1209                 1                19                      2
#
#      WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 457                3               0                   0
# 828                3               0                   0
# 1153               4               0                   0
# 1311               1               0                   0
# 301                3               0                   0
# 972                4               0                   0
# 727                3               0                   0
# 296                3               0                   0
# 127                2               0                   0
# 177                2               1                   0
# 232                2               2                   2
# 6                  2               1                   0
# 919                2               9                   7
# 743                3               5                   3
# 225                3               1                   0
# 427                4              18                  13
# 411                1              29                   8
# 536                3               2                   2
# 879                3              11                   7
# 1209               4               1                   0
#
#       YearsSinceLastPromotion YearsWithCurrManager
# 457                         0                    0
# 828                         0                    0
# 1153                        0                    0
# 1311                        0                    0
# 301                         0                    0
# 972                         0                    0
# 727                         0                    0
# 296                         0                    0
# 127                         0                    0
# 177                         1                    0
# 232                         2                    2
# 6                           0                    0
# 919                         5                    4
# 743                         4                    3
# 225                         0                    0
# 427                        13                   11
# 411                        11                   10
# 536                         2                    2
# 879                         1                    9
# 1209                        0                    0
#
# [20 rows x 31 columns]

# %% [markdown]
# ### Mostrando separadamente usando nlargest e nsmallest

# %%
df_funcionarios_mais_novos = df_colunas_removidas.nsmallest(10, "Age")
display(df_funcionarios_mais_novos)

df_funcionarios_mais_velhos = df_colunas_removidas.nlargest(10, "Age")
display(df_funcionarios_mais_velhos)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 296    18       Yes      Travel_Rarely        230  Research & Development
# 301    18        No      Travel_Rarely        812                   Sales
# 457    18       Yes  Travel_Frequently       1306                   Sales
# 727    18        No         Non-Travel        287  Research & Development
# 828    18       Yes         Non-Travel        247  Research & Development
# 972    18        No         Non-Travel       1124  Research & Development
# 1153   18       Yes  Travel_Frequently        544                   Sales
# 1311   18        No         Non-Travel       1431  Research & Development
# 127    19       Yes      Travel_Rarely        528                   Sales
# 149    19        No      Travel_Rarely       1181  Research & Development
#
#       DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 296                  3          3  Life Sciences                        3
# 301                 10          3        Medical                        4
# 457                  5          3      Marketing                        2
# 727                  5          2  Life Sciences                        2
# 828                  8          1        Medical                        3
# 972                  1          3  Life Sciences                        4
# 1153                 3          2        Medical                        2
# 1311                14          3        Medical                        2
# 127                 22          1      Marketing                        4
# 149                  3          1        Medical                        2
#
#       Gender  ...  PerformanceRating  RelationshipSatisfaction  \
# 296     Male  ...                  3                         3
# 301   Female  ...                  3                         1
# 457     Male  ...                  3                         4
# 727     Male  ...                  3                         4
# 828     Male  ...                  3                         4
# 972   Female  ...                  3                         3
# 1153  Female  ...                  3                         3
# 1311  Female  ...                  3                         3
# 127     Male  ...                  3                         4
# 149   Female  ...                  3                         4
#
#       StockOptionLevel TotalWorkingYears  TrainingTimesLastYear  \
# 296                  0                 0                      2
# 301                  0                 0                      2
# 457                  0                 0                      3
# 727                  0                 0                      2
# 828                  0                 0                      0
# 972                  0                 0                      5
# 1153                 0                 0                      2
# 1311                 0                 0                      4
# 127                  0                 0                      2
# 149                  0                 1                      3
#
#      WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 296                3               0                   0
# 301                3               0                   0
# 457                3               0                   0
# 727                3               0                   0
# 828                3               0                   0
# 972                4               0                   0
# 1153               4               0                   0
# 1311               1               0                   0
# 127                2               0                   0
# 149                3               1                   0
#
#       YearsSinceLastPromotion YearsWithCurrManager
# 296                         0                    0
# 301                         0                    0
# 457                         0                    0
# 727                         0                    0
# 828                         0                    0
# 972                         0                    0
# 1153                        0                    0
# 1311                        0                    0
# 127                         0                    0
# 149                         0                    0
#
# [10 rows x 31 columns]
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 411    60        No      Travel_Rarely        422  Research & Development
# 427    60        No  Travel_Frequently       1499                   Sales
# 536    60        No      Travel_Rarely       1179                   Sales
# 879    60        No      Travel_Rarely        696                   Sales
# 1209   60        No      Travel_Rarely        370  Research & Development
# 6      59        No      Travel_Rarely       1324  Research & Development
# 63     59        No      Travel_Rarely       1435                   Sales
# 70     59        No  Travel_Frequently       1225                   Sales
# 105    59        No         Non-Travel       1420         Human Resources
# 225    59        No      Travel_Rarely        142  Research & Development
#
#       DistanceFromHome  Education   EducationField  EnvironmentSatisfaction  \
# 411                  7          3    Life Sciences                        1
# 427                 28          3        Marketing                        3
# 536                 16          4        Marketing                        1
# 879                  7          4        Marketing                        2
# 1209                 1          4          Medical                        3
# 6                    3          3          Medical                        3
# 63                  25          3    Life Sciences                        1
# 70                   1          1    Life Sciences                        1
# 105                  2          4  Human Resources                        3
# 225                  3          3    Life Sciences                        3
#
#       Gender  ...  PerformanceRating  RelationshipSatisfaction  \
# 411   Female  ...                  3                         4
# 427   Female  ...                  3                         4
# 536     Male  ...                  3                         4
# 879     Male  ...                  3                         2
# 1209    Male  ...                  4                         3
# 6     Female  ...                  4                         1
# 63    Female  ...                  3                         4
# 70    Female  ...                  3                         4
# 105   Female  ...                  4                         4
# 225     Male  ...                  3                         1
#
#       StockOptionLevel TotalWorkingYears  TrainingTimesLastYear  \
# 411                  0                33                      5
# 427                  0                22                      5
# 536                  0                10                      1
# 879                  1                12                      3
# 1209                 1                19                      2
# 6                    3                12                      3
# 63                   0                28                      3
# 70                   0                20                      2
# 105                  1                30                      3
# 225                  1                 7                      6
#
#      WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 411                1              29                   8
# 427                4              18                  13
# 536                3               2                   2
# 879                3              11                   7
# 1209               4               1                   0
# 6                  2               1                   0
# 63                 2              21                  16
# 70                 2               4                   3
# 105                3               3                   2
# 225                3               1                   0
#
#       YearsSinceLastPromotion YearsWithCurrManager
# 411                        11                   10
# 427                        13                   11
# 536                         2                    2
# 879                         1                    9
# 1209                        0                    0
# 6                           0                    0
# 63                          7                    9
# 70                          1                    3
# 105                         2                    2
# 225                         0                    0
#
# [10 rows x 31 columns]

# %% [markdown]
# * Encontrar os registros dos 10 funcionários com mais tempo de empresa e dos 10 com menos tempo

# %%
display(
    df_colunas_removidas.nlargest(10, "TotalWorkingYears")
)


display(
    df_colunas_removidas.nsmallest(10, "TotalWorkingYears")
)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 126    58       Yes      Travel_Rarely        147  Research & Development
# 595    58       Yes      Travel_Rarely        286  Research & Development
# 98     58        No      Travel_Rarely        682                   Sales
# 85     56        No      Travel_Rarely       1400  Research & Development
# 270    55        No      Travel_Rarely        452  Research & Development
# 445    55        No      Travel_Rarely       1117                   Sales
# 1301   58        No         Non-Travel        350                   Sales
# 187    55        No      Travel_Rarely        692  Research & Development
# 401    56        No  Travel_Frequently        906                   Sales
# 894    54        No      Travel_Rarely        685  Research & Development
#
#       DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 126                 23          4        Medical                        4
# 595                  2          4  Life Sciences                        4
# 98                  10          4        Medical                        4
# 85                   7          3  Life Sciences                        4
# 270                  1          3        Medical                        4
# 445                 18          5  Life Sciences                        1
# 1301                 2          3        Medical                        2
# 187                 14          4        Medical                        3
# 401                  6          3  Life Sciences                        3
# 894                  3          3  Life Sciences                        4
#
#       Gender  ...  PerformanceRating  RelationshipSatisfaction  \
# 126   Female  ...                  3                         4
# 595     Male  ...                  3                         4
# 98      Male  ...                  3                         3
# 85      Male  ...                  3                         1
# 270     Male  ...                  3                         3
# 445   Female  ...                  4                         4
# 1301    Male  ...                  4                         4
# 187     Male  ...                  3                         4
# 401   Female  ...                  3                         4
# 894     Male  ...                  3                         1
#
#       StockOptionLevel TotalWorkingYears  TrainingTimesLastYear  \
# 126                  1                40                      3
# 595                  0                40                      2
# 98                   0                38                      1
# 85                   0                37                      3
# 270                  0                37                      2
# 445                  0                37                      2
# 1301                 1                37                      0
# 187                  0                36                      3
# 401                  3                36                      0
# 894                  0                36                      2
#
#      WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 126                2              40                  10
# 595                3              31                  15
# 98                 2              37                  10
# 85                 2               6                   4
# 270                3              36                  10
# 445                3              10                   9
# 1301               2              16                   9
# 187                3              24                  15
# 401                2               7                   7
# 894                3              10                   9
#
#       YearsSinceLastPromotion YearsWithCurrManager
# 126                        15                    6
# 595                        13                    8
# 98                          1                    8
# 85                          0                    2
# 270                         4                   13
# 445                         7                    7
# 1301                       14                   14
# 187                         2                   15
# 401                         7                    7
# 894                         0                    9
#
# [10 rows x 31 columns]
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 23     21        No      Travel_Rarely        391  Research & Development
# 127    19       Yes      Travel_Rarely        528                   Sales
# 296    18       Yes      Travel_Rarely        230  Research & Development
# 301    18        No      Travel_Rarely        812                   Sales
# 457    18       Yes  Travel_Frequently       1306                   Sales
# 615    27        No         Non-Travel        443  Research & Development
# 727    18        No         Non-Travel        287  Research & Development
# 828    18       Yes         Non-Travel        247  Research & Development
# 972    18        No         Non-Travel       1124  Research & Development
# 1153   18       Yes  Travel_Frequently        544                   Sales
#
#       DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 23                  15          2  Life Sciences                        3
# 127                 22          1      Marketing                        4
# 296                  3          3  Life Sciences                        3
# 301                 10          3        Medical                        4
# 457                  5          3      Marketing                        2
# 615                  3          3        Medical                        4
# 727                  5          2  Life Sciences                        2
# 828                  8          1        Medical                        3
# 972                  1          3  Life Sciences                        4
# 1153                 3          2        Medical                        2
#
#       Gender  ...  PerformanceRating  RelationshipSatisfaction  \
# 23      Male  ...                  3                         4
# 127     Male  ...                  3                         4
# 296     Male  ...                  3                         3
# 301   Female  ...                  3                         1
# 457     Male  ...                  3                         4
# 615     Male  ...                  3                         3
# 727     Male  ...                  3                         4
# 828     Male  ...                  3                         4
# 972   Female  ...                  3                         3
# 1153  Female  ...                  3                         3
#
#       StockOptionLevel TotalWorkingYears  TrainingTimesLastYear  \
# 23                   0                 0                      6
# 127                  0                 0                      2
# 296                  0                 0                      2
# 301                  0                 0                      2
# 457                  0                 0                      3
# 615                  3                 0                      6
# 727                  0                 0                      2
# 828                  0                 0                      0
# 972                  0                 0                      5
# 1153                 0                 0                      2
#
#      WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 23                 3               0                   0
# 127                2               0                   0
# 296                3               0                   0
# 301                3               0                   0
# 457                3               0                   0
# 615                2               0                   0
# 727                3               0                   0
# 828                3               0                   0
# 972                4               0                   0
# 1153               4               0                   0
#
#       YearsSinceLastPromotion YearsWithCurrManager
# 23                          0                    0
# 127                         0                    0
# 296                         0                    0
# 301                         0                    0
# 457                         0                    0
# 615                         0                    0
# 727                         0                    0
# 828                         0                    0
# 972                         0                    0
# 1153                        0                    0
#
# [10 rows x 31 columns]

# %% [markdown]
# * Encontrar os registros dos 10 funcionários com mais tempo no cargo (sem promoção) e dos 10 com menos tempo

# %%
display(
    df_colunas_removidas.nlargest(10, "YearsSinceLastPromotion")
)

display(
    df_colunas_removidas.nsmallest(10, "YearsSinceLastPromotion")
)
# Out:
#      Age Attrition BusinessTravel  DailyRate              Department  \
# 45    41       Yes  Travel_Rarely       1360  Research & Development
# 123   51        No  Travel_Rarely        684  Research & Development
# 126   58       Yes  Travel_Rarely        147  Research & Development
# 178   46        No  Travel_Rarely        526                   Sales
# 237   52        No     Non-Travel        771                   Sales
# 425   50        No  Travel_Rarely       1099  Research & Development
# 701   53        No  Travel_Rarely       1376                   Sales
# 752   36       Yes  Travel_Rarely        885  Research & Development
# 861   46        No  Travel_Rarely       1402                   Sales
# 914   55        No     Non-Travel        177  Research & Development
#
#      DistanceFromHome  Education    EducationField  EnvironmentSatisfaction  \
# 45                 12          3  Technical Degree                        2
# 123                 6          3     Life Sciences                        1
# 126                23          4           Medical                        4
# 178                 1          2         Marketing                        2
# 237                 2          4     Life Sciences                        1
# 425                29          4     Life Sciences                        2
# 701                 2          2           Medical                        3
# 752                16          4     Life Sciences                        3
# 861                 2          3         Marketing                        3
# 914                 8          1           Medical                        4
#
#      Gender  ...  PerformanceRating  RelationshipSatisfaction  \
# 45   Female  ...                  3                         4
# 123    Male  ...                  3                         3
# 126  Female  ...                  3                         4
# 178  Female  ...                  4                         3
# 237    Male  ...                  3                         4
# 425    Male  ...                  3                         2
# 701    Male  ...                  3                         3
# 752  Female  ...                  3                         3
# 861  Female  ...                  4                         1
# 914    Male  ...                  3                         4
#
#      StockOptionLevel TotalWorkingYears  TrainingTimesLastYear  \
# 45                  0                23                      0
# 123                 0                23                      5
# 126                 1                40                      3
# 178                 3                24                      2
# 237                 0                33                      2
# 425                 1                28                      2
# 701                 1                22                      3
# 752                 0                18                      1
# 861                 0                28                      2
# 914                 1                34                      3
#
#     WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 45                3              22                  15
# 123               3              20                  18
# 126               2              40                  10
# 178               3              24                  13
# 237               4              33                   7
# 425               3              27                  10
# 701               4              17                  13
# 752               3              17                  13
# 861               3              26                  15
# 914               3              33                   9
#
#      YearsSinceLastPromotion YearsWithCurrManager
# 45                        15                    8
# 123                       15                   15
# 126                       15                    6
# 178                       15                    7
# 237                       15                   12
# 425                       15                    7
# 701                       15                    2
# 752                       15                   14
# 861                       15                    9
# 914                       15                    0
#
# [10 rows x 31 columns]
#     Age Attrition BusinessTravel  DailyRate              Department  \
# 0    41       Yes  Travel_Rarely       1102                   Sales
# 2    37       Yes  Travel_Rarely       1373  Research & Development
# 6    59        No  Travel_Rarely       1324  Research & Development
# 7    30        No  Travel_Rarely       1358  Research & Development
# 10   35        No  Travel_Rarely        809  Research & Development
# 11   29        No  Travel_Rarely        153  Research & Development
# 14   28       Yes  Travel_Rarely        103  Research & Development
# 16   32        No  Travel_Rarely        334  Research & Development
# 17   22        No     Non-Travel       1123  Research & Development
# 21   36       Yes  Travel_Rarely       1218                   Sales
#
#     DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                  1          2  Life Sciences                        2
# 2                  2          2          Other                        4
# 6                  3          3        Medical                        3
# 7                 24          1  Life Sciences                        4
# 10                16          3        Medical                        1
# 11                15          2  Life Sciences                        4
# 14                24          3  Life Sciences                        3
# 16                 5          2  Life Sciences                        1
# 17                16          2        Medical                        4
# 21                 9          4  Life Sciences                        3
#
#     Gender  ...  PerformanceRating  RelationshipSatisfaction  \
# 0   Female  ...                  3                         1
# 2     Male  ...                  3                         2
# 6   Female  ...                  4                         1
# 7     Male  ...                  4                         2
# 10    Male  ...                  3                         3
# 11  Female  ...                  3                         4
# 14    Male  ...                  3                         2
# 16    Male  ...                  3                         4
# 17    Male  ...                  3                         2
# 21    Male  ...                  4                         2
#
#     StockOptionLevel TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  \
# 0                  0                 8                      0               1
# 2                  0                 7                      3               3
# 6                  3                12                      3               2
# 7                  1                 1                      2               3
# 10                 1                 6                      5               3
# 11                 0                10                      3               3
# 14                 0                 6                      4               3
# 16                 2                 7                      5               2
# 17                 2                 1                      2               2
# 21                 0                10                      4               3
#
#     YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0                6                   4                        0
# 2                0                   0                        0
# 6                1                   0                        0
# 7                1                   0                        0
# 10               5                   4                        0
# 11               9                   5                        0
# 14               4                   2                        0
# 16               6                   2                        0
# 17               1                   0                        0
# 21               5                   3                        0
#
#    YearsWithCurrManager
# 0                     5
# 2                     0
# 6                     0
# 7                     0
# 10                    3
# 11                    8
# 14                    3
# 16                    5
# 17                    0
# 21                    3
#
# [10 rows x 31 columns]

# %% [markdown]
# ### Analisando as situações de pessoas que tem maior tempo sem aumento

# %%
display(
    df_colunas_removidas.nlargest(
        n=10, 
        columns="YearsSinceLastPromotion"
    )[["Age", "JobRole", "YearsSinceLastPromotion", "JobLevel", "YearsAtCompany"]]
)
# Out:
#      Age                    JobRole  YearsSinceLastPromotion  JobLevel  \
# 45    41          Research Director                       15         5
# 123   51          Research Director                       15         5
# 126   58  Healthcare Representative                       15         3
# 178   46            Sales Executive                       15         3
# 237   52                    Manager                       15         5
# 425   50                    Manager                       15         4
# 701   53                    Manager                       15         4
# 752   36      Laboratory Technician                       15         1
# 861   46                    Manager                       15         4
# 914   55  Healthcare Representative                       15         4
#
#      YearsAtCompany
# 45               22
# 123              20
# 126              40
# 178              24
# 237              33
# 425              27
# 701              17
# 752              17
# 861              26
# 914              33

# %% [markdown]
# ### Analisando as situações de pessoas que tem menos tempo sem aumento

# %%
display(
    df_colunas_removidas.nsmallest(
        n=10, 
        columns="YearsSinceLastPromotion"
    )[["Age", "JobRole", "YearsSinceLastPromotion", "JobLevel", "YearsAtCompany"]]
)
# Out:
#     Age                JobRole  YearsSinceLastPromotion  JobLevel  \
# 0    41        Sales Executive                        0         2
# 2    37  Laboratory Technician                        0         1
# 6    59  Laboratory Technician                        0         1
# 7    30  Laboratory Technician                        0         1
# 10   35  Laboratory Technician                        0         1
# 11   29  Laboratory Technician                        0         2
# 14   28  Laboratory Technician                        0         1
# 16   32     Research Scientist                        0         1
# 17   22  Laboratory Technician                        0         1
# 21   36   Sales Representative                        0         1
#
#     YearsAtCompany
# 0                6
# 2                0
# 6                1
# 7                1
# 10               5
# 11               9
# 14               4
# 16               6
# 17               1
# 21               5

# %%
colunas_categoricas_nao_ordenadas = [
    "BusinessTravel",
    "Department",
    "EducationField",
    "Gender",
    "JobRole",
    "MaritalStatus",
    "OverTime",
]

colunas_categoricas_ordenadas = [
    "Education",
    "EnvironmentSatisfaction",
    "JobInvolvement",
    "JobSatisfaction",
    "JobLevel",
    "PerformanceRating",
    "RelationshipSatisfaction",
    "StockOptionLevel",
    "WorkLifeBalance",
]

colunas_alvos = [
    "Attrition"
]

colunas_numericas = [
    coluna for coluna in df_colunas_removidas.columns \
        if coluna not in (colunas_categoricas_nao_ordenadas + colunas_categoricas_ordenadas + colunas_alvos)
    ]

display(df_colunas_removidas[colunas_numericas])
# Out:
#       Age  DailyRate  DistanceFromHome  HourlyRate  MonthlyIncome  \
# 0      41       1102                 1          94           5993
# 1      49        279                 8          61           5130
# 2      37       1373                 2          92           2090
# 3      33       1392                 3          56           2909
# 4      27        591                 2          40           3468
# ...   ...        ...               ...         ...            ...
# 1465   36        884                23          41           2571
# 1466   39        613                 6          42           9991
# 1467   27        155                 4          87           6142
# 1468   49       1023                 2          63           5390
# 1469   34        628                 8          82           4404
#
#       MonthlyRate  NumCompaniesWorked  PercentSalaryHike  TotalWorkingYears  \
# 0           19479                   8                 11                  8
# 1           24907                   1                 23                 10
# 2            2396                   6                 15                  7
# 3           23159                   1                 11                  8
# 4           16632                   9                 12                  6
# ...           ...                 ...                ...                ...
# 1465        12290                   4                 17                 17
# 1466        21457                   4                 15                  9
# 1467         5174                   1                 20                  6
# 1468        13243                   2                 14                 17
# 1469        10228                   2                 12                  6
#
#       TrainingTimesLastYear  YearsAtCompany  YearsInCurrentRole  \
# 0                         0               6                   4
# 1                         3              10                   7
# 2                         3               0                   0
# 3                         3               8                   7
# 4                         3               2                   2
# ...                     ...             ...                 ...
# 1465                      3               5                   2
# 1466                      5               7                   7
# 1467                      0               6                   2
# 1468                      3               9                   6
# 1469                      3               4                   3
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                           0                     5
# 1                           1                     7
# 2                           0                     0
# 3                           3                     0
# 4                           2                     2
# ...                       ...                   ...
# 1465                        0                     3
# 1466                        1                     7
# 1467                        0                     3
# 1468                        0                     8
# 1469                        1                     2
#
# [1470 rows x 14 columns]

# %%
# Listagem de todos as colunas categoricas
colunas_categoricas_totais = colunas_categoricas_nao_ordenadas + colunas_categoricas_ordenadas

# Identificando o maior tamanho no nome da coluna
contador = {coluna: len(coluna) for coluna in colunas_categoricas_totais}

for coluna in colunas_categoricas_totais:
    print(f"{coluna:<{max(contador.values())}}: {df_colunas_removidas[coluna].unique()}")
# Out:
# BusinessTravel          : ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# Department              : ['Sales' 'Research & Development' 'Human Resources']
# EducationField          : ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
# Gender                  : ['Female' 'Male']
# JobRole                 : ['Sales Executive' 'Research Scientist' 'Laboratory Technician'
#  'Manufacturing Director' 'Healthcare Representative' 'Manager'
#  'Sales Representative' 'Research Director' 'Human Resources']
# MaritalStatus           : ['Single' 'Married' 'Divorced']
# OverTime                : ['Yes' 'No']
# Education               : [2 1 4 3 5]
# EnvironmentSatisfaction : [2 3 4 1]
# JobInvolvement          : [3 2 4 1]
# JobSatisfaction         : [4 2 3 1]
# JobLevel                : [2 1 3 4 5]
# PerformanceRating       : [3 4]
# RelationshipSatisfaction: [1 4 2 3]
# StockOptionLevel        : [0 1 3 2]
# WorkLifeBalance         : [1 3 2 4]

# %% [markdown]
# ### Identificando o tamanho da base de dados

# %%
df_colunas_removidas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EnvironmentSatisfaction   1470 non-null   int64
#  9   Gender                    1470 non-null   object
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   int64
#  12  JobLevel                  1470 non-null   int64
#  13  JobRole                   1470 non-null   object
#  14  JobSatisfaction           1470 non-null   int64
#  15  MaritalStatus             1470 non-null   object
#  16  MonthlyIncome             1470 non-null   int64
#  17  MonthlyRate               1470 non-null   int64
#  18  NumCompaniesWorked        1470 non-null   int64
#  19  OverTime                  1470 non-null   object
#  20  PercentSalaryHike         1470 non-null   int64
#  21  PerformanceRating         1470 non-null   int64
#  22  RelationshipSatisfaction  1470 non-null   int64
#  23  StockOptionLevel          1470 non-null   int64
#  24  TotalWorkingYears         1470 non-null   int64
#  25  TrainingTimesLastYear     1470 non-null   int64
#  26  WorkLifeBalance           1470 non-null   int64
#  27  YearsAtCompany            1470 non-null   int64
#  28  YearsInCurrentRole        1470 non-null   int64
#  29  YearsSinceLastPromotion   1470 non-null   int64
#  30  YearsWithCurrManager      1470 non-null   int64
# dtypes: int64(23), object(8)
# memory usage: 356.1+ KB

# %% [markdown]
# ### Transformando os tipos não ordenados para categoria

# %%
for coluna in colunas_categoricas_nao_ordenadas:
    df_colunas_removidas[coluna] = df_colunas_removidas[coluna].astype("category")

# %% [markdown]
# ### Reduzindo o tamanho da base de dados após a mudança dos itens para categoria

# %%
df_colunas_removidas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   category
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   category
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   category
#  8   EnvironmentSatisfaction   1470 non-null   int64
#  9   Gender                    1470 non-null   category
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   int64
#  12  JobLevel                  1470 non-null   int64
#  13  JobRole                   1470 non-null   category
#  14  JobSatisfaction           1470 non-null   int64
#  15  MaritalStatus             1470 non-null   category
#  16  MonthlyIncome             1470 non-null   int64
#  17  MonthlyRate               1470 non-null   int64
#  18  NumCompaniesWorked        1470 non-null   int64
#  19  OverTime                  1470 non-null   category
#  20  PercentSalaryHike         1470 non-null   int64
#  21  PerformanceRating         1470 non-null   int64
#  22  RelationshipSatisfaction  1470 non-null   int64
#  23  StockOptionLevel          1470 non-null   int64
#  24  TotalWorkingYears         1470 non-null   int64
#  25  TrainingTimesLastYear     1470 non-null   int64
#  26  WorkLifeBalance           1470 non-null   int64
#  27  YearsAtCompany            1470 non-null   int64
#  28  YearsInCurrentRole        1470 non-null   int64
#  29  YearsSinceLastPromotion   1470 non-null   int64
#  30  YearsWithCurrManager      1470 non-null   int64
# dtypes: category(7), int64(23), object(1)
# memory usage: 287.0+ KB

# %%
for coluna in df_colunas_removidas.select_dtypes("category"):
    print(f"{coluna}")
    print(f"Categories: {df_colunas_removidas[coluna].cat.categories}")
    print(f"Ordered: {df_colunas_removidas[coluna].cat.ordered}")
    print(f"Codes: {df_colunas_removidas[coluna].cat.codes.unique()}")
    print()
# Out:
# BusinessTravel
# Categories: Index(['Non-Travel', 'Travel_Frequently', 'Travel_Rarely'], dtype='object')
# Ordered: False
# Codes: [2 1 0]
#
# Department
# Categories: Index(['Human Resources', 'Research & Development', 'Sales'], dtype='object')
# Ordered: False
# Codes: [2 1 0]
#
# EducationField
# Categories: Index(['Human Resources', 'Life Sciences', 'Marketing', 'Medical', 'Other',
#        'Technical Degree'],
#       dtype='object')
# Ordered: False
# Codes: [1 4 3 2 5 0]
#
# Gender
# Categories: Index(['Female', 'Male'], dtype='object')
# Ordered: False
# Codes: [0 1]
#
# JobRole
# Categories: Index(['Healthcare Representative', 'Human Resources', 'Laboratory Technician',
#        'Manager', 'Manufacturing Director', 'Research Director',
#        'Research Scientist', 'Sales Executive', 'Sales Representative'],
#       dtype='object')
# Ordered: False
# Codes: [7 6 2 4 0 3 8 5 1]
#
# MaritalStatus
# Categories: Index(['Divorced', 'Married', 'Single'], dtype='object')
# Ordered: False
# Codes: [2 1 0]
#
# OverTime
# Categories: Index(['No', 'Yes'], dtype='object')
# Ordered: False
# Codes: [1 0]

# %%
display(
    df_colunas_removidas["Department"].value_counts().plot(kind="bar")
)
# Out:
# <Axes: xlabel='Department'>

# %% [markdown]
# * Agrupamentos: contagem de funcionários por departamento

# %%
df_contagem_funcionarios_por_departamento = df_colunas_removidas.pivot_table(
    index="Department", columns="Attrition", aggfunc="size", observed=False)
df_contagem_funcionarios_por_departamento.insert(
        len(df_contagem_funcionarios_por_departamento.columns), 
        "Total", 
        df_contagem_funcionarios_por_departamento["No"] + df_contagem_funcionarios_por_departamento["Yes"]
    )
df_contagem_funcionarios_por_departamento.loc["Total"] = df_contagem_funcionarios_por_departamento.sum(0).values
display(df_contagem_funcionarios_por_departamento)

df_contagem_funcionarios_por_departamento.drop(columns="Total")[:-1].plot(kind="bar")
# Out:
# Attrition                 No  Yes  Total
# Department
# Human Resources           51   12     63
# Research & Development   828  133    961
# Sales                    354   92    446
# Total                   1233  237   1470
# <Axes: xlabel='Department'>

# %% [markdown]
# O `crosstab` do Pandas é uma função muito útil para criar tabelas de contingência, que são tabelas que resumem a relação entre duas ou mais variáveis. De maneira simplificada, crosstab permite-nos contar quantas vezes cada combinação de valores das variáveis ocorre no dataset. Isso é especialmente útil para análise exploratória de dados, permitindo entender melhor a distribuição e a relação entre variáveis categóricas.

# %%
pd.crosstab(
    df_colunas_removidas["Department"], 
    df_colunas_removidas["Attrition"],
)
# Out:
# Attrition                No  Yes
# Department
# Human Resources          51   12
# Research & Development  828  133
# Sales                   354   92

# %% [markdown]
# Colormaps: https://matplotlib.org/stable/users/explain/colors/colormaps.html

# %%
print("Análise considerando valores totais")
display(
    pd.crosstab(
        df_colunas_removidas["Department"], 
        df_colunas_removidas["Attrition"], 
        normalize=True
    ).style.background_gradient(
        cmap="RdYlGn"
    ).format(
        "{:.2%}"
    )
)

print("Análise considerando valores dos índices")
display(
    pd.crosstab(
        df_colunas_removidas["Department"], 
        df_colunas_removidas["Attrition"], 
        normalize="index"
    ).style.background_gradient(
        cmap="Spectral", 
        axis="columns"
    ).format(
        "{:.2%}"
    )
)

print("Análise considerando valores das colunas")
display(
    pd.crosstab(
        df_colunas_removidas["Department"], 
        df_colunas_removidas["Attrition"], 
        normalize="columns"
    ).style.background_gradient(
        cmap="coolwarm", 
        axis="columns"
    ).format(
        "{:.2%}"
    )
)
# Out:
# Análise considerando valores totais
# <style type="text/css">
# #T_8700a_row0_col0, #T_8700a_row0_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_8700a_row1_col0, #T_8700a_row1_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_8700a_row2_col0 {
#   background-color: #feda86;
#   color: #000000;
# }
# #T_8700a_row2_col1 {
#   background-color: #b9e176;
#   color: #000000;
# }
# </style>
# <table id="T_8700a">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Attrition</th>
#       <th id="T_8700a_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_8700a_level0_col1" class="col_heading level0 col1" >Yes</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Department</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8700a_level0_row0" class="row_heading level0 row0" >Human Resources</th>
#       <td id="T_8700a_row0_col0" class="data row0 col0" >3.47%</td>
#       <td id="T_8700a_row0_col1" class="data row0 col1" >0.82%</td>
#     </tr>
#     <tr>
#       <th id="T_8700a_level0_row1" class="row_heading level0 row1" >Research & Development</th>
#       <td id="T_8700a_row1_col0" class="data row1 col0" >56.33%</td>
#       <td id="T_8700a_row1_col1" class="data row1 col1" >9.05%</td>
#     </tr>
#     <tr>
#       <th id="T_8700a_level0_row2" class="row_heading level0 row2" >Sales</th>
#       <td id="T_8700a_row2_col0" class="data row2 col0" >24.08%</td>
#       <td id="T_8700a_row2_col1" class="data row2 col1" >6.26%</td>
#     </tr>
#   </tbody>
# </table>
# Análise considerando valores dos índices
# <style type="text/css">
# #T_d981b_row0_col0, #T_d981b_row1_col0, #T_d981b_row2_col0 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_d981b_row0_col1, #T_d981b_row1_col1, #T_d981b_row2_col1 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d981b">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Attrition</th>
#       <th id="T_d981b_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_d981b_level0_col1" class="col_heading level0 col1" >Yes</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Department</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d981b_level0_row0" class="row_heading level0 row0" >Human Resources</th>
#       <td id="T_d981b_row0_col0" class="data row0 col0" >80.95%</td>
#       <td id="T_d981b_row0_col1" class="data row0 col1" >19.05%</td>
#     </tr>
#     <tr>
#       <th id="T_d981b_level0_row1" class="row_heading level0 row1" >Research & Development</th>
#       <td id="T_d981b_row1_col0" class="data row1 col0" >86.16%</td>
#       <td id="T_d981b_row1_col1" class="data row1 col1" >13.84%</td>
#     </tr>
#     <tr>
#       <th id="T_d981b_level0_row2" class="row_heading level0 row2" >Sales</th>
#       <td id="T_d981b_row2_col0" class="data row2 col0" >79.37%</td>
#       <td id="T_d981b_row2_col1" class="data row2 col1" >20.63%</td>
#     </tr>
#   </tbody>
# </table>
# Análise considerando valores das colunas
# <style type="text/css">
# #T_f4360_row0_col0, #T_f4360_row1_col1, #T_f4360_row2_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_f4360_row0_col1, #T_f4360_row1_col0, #T_f4360_row2_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f4360">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Attrition</th>
#       <th id="T_f4360_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_f4360_level0_col1" class="col_heading level0 col1" >Yes</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Department</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f4360_level0_row0" class="row_heading level0 row0" >Human Resources</th>
#       <td id="T_f4360_row0_col0" class="data row0 col0" >4.14%</td>
#       <td id="T_f4360_row0_col1" class="data row0 col1" >5.06%</td>
#     </tr>
#     <tr>
#       <th id="T_f4360_level0_row1" class="row_heading level0 row1" >Research & Development</th>
#       <td id="T_f4360_row1_col0" class="data row1 col0" >67.15%</td>
#       <td id="T_f4360_row1_col1" class="data row1 col1" >56.12%</td>
#     </tr>
#     <tr>
#       <th id="T_f4360_level0_row2" class="row_heading level0 row2" >Sales</th>
#       <td id="T_f4360_row2_col0" class="data row2 col0" >28.71%</td>
#       <td id="T_f4360_row2_col1" class="data row2 col1" >38.82%</td>
#     </tr>
#   </tbody>
# </table>

# %%
pd.crosstab(
    df_colunas_removidas["Department"], 
    df_colunas_removidas["Attrition"], 
    margins=True, 
    margins_name="Total"
)
# Out:
# Attrition                 No  Yes  Total
# Department
# Human Resources           51   12     63
# Research & Development   828  133    961
# Sales                    354   92    446
# Total                   1233  237   1470

# %% [markdown]
# * Agrupamentos: média de salário por departamento

# %%
with pd.option_context("float_format", "$ {:_.2f}".format):
    display(
        df_colunas_removidas.pivot_table(
            index="Department", 
            columns="Attrition", 
            aggfunc="mean", 
            values="MonthlyIncome", 
            observed=False
        )
    )
# Out:
# Attrition                      No        Yes
# Department
# Human Resources        $ 7_345.98 $ 3_715.75
# Research & Development $ 6_630.33 $ 4_108.08
# Sales                  $ 7_232.24 $ 5_908.46

# %%
df_colunas_removidas.pivot_table(
    index="Department", 
    columns="Attrition", 
    aggfunc="mean", 
    values="MonthlyIncome", 
    observed=False
).plot(
    kind="bar", 
    title="Média de salário por departamento"
)
# Out:
# <Axes: title={'center': 'Média de salário por departamento'}, xlabel='Department'>

# %%
df_colunas_removidas.groupby(
    by=["Department", "Attrition"], 
    observed=False,
)["MonthlyIncome"].mean().to_frame().unstack(1).style.format("$ {:_.2f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_4b762">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4b762_level0_col0" class="col_heading level0 col0" colspan="2">MonthlyIncome</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Attrition</th>
#       <th id="T_4b762_level1_col0" class="col_heading level1 col0" >No</th>
#       <th id="T_4b762_level1_col1" class="col_heading level1 col1" >Yes</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Department</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4b762_level0_row0" class="row_heading level0 row0" >Human Resources</th>
#       <td id="T_4b762_row0_col0" class="data row0 col0" >$ 7_345.98</td>
#       <td id="T_4b762_row0_col1" class="data row0 col1" >$ 3_715.75</td>
#     </tr>
#     <tr>
#       <th id="T_4b762_level0_row1" class="row_heading level0 row1" >Research & Development</th>
#       <td id="T_4b762_row1_col0" class="data row1 col0" >$ 6_630.33</td>
#       <td id="T_4b762_row1_col1" class="data row1 col1" >$ 4_108.08</td>
#     </tr>
#     <tr>
#       <th id="T_4b762_level0_row2" class="row_heading level0 row2" >Sales</th>
#       <td id="T_4b762_row2_col0" class="data row2 col0" >$ 7_232.24</td>
#       <td id="T_4b762_row2_col1" class="data row2 col1" >$ 5_908.46</td>
#     </tr>
#   </tbody>
# </table>

# %%
pd.crosstab(
    df_colunas_removidas["Department"], 
    df_colunas_removidas["Attrition"], 
    aggfunc="mean", 
    values=df_colunas_removidas["MonthlyIncome"],
).style.background_gradient(
    cmap="Blues", 
    axis="columns"
).format(
    "$ {:_.2f}"
)
# Out:
# <style type="text/css">
# #T_31c06_row0_col0, #T_31c06_row1_col0, #T_31c06_row2_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_31c06_row0_col1, #T_31c06_row1_col1, #T_31c06_row2_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_31c06">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Attrition</th>
#       <th id="T_31c06_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_31c06_level0_col1" class="col_heading level0 col1" >Yes</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Department</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_31c06_level0_row0" class="row_heading level0 row0" >Human Resources</th>
#       <td id="T_31c06_row0_col0" class="data row0 col0" >$ 7_345.98</td>
#       <td id="T_31c06_row0_col1" class="data row0 col1" >$ 3_715.75</td>
#     </tr>
#     <tr>
#       <th id="T_31c06_level0_row1" class="row_heading level0 row1" >Research & Development</th>
#       <td id="T_31c06_row1_col0" class="data row1 col0" >$ 6_630.33</td>
#       <td id="T_31c06_row1_col1" class="data row1 col1" >$ 4_108.08</td>
#     </tr>
#     <tr>
#       <th id="T_31c06_level0_row2" class="row_heading level0 row2" >Sales</th>
#       <td id="T_31c06_row2_col0" class="data row2 col0" >$ 7_232.24</td>
#       <td id="T_31c06_row2_col1" class="data row2 col1" >$ 5_908.46</td>
#     </tr>
#   </tbody>
# </table>

# %%
display(
    df_colunas_removidas.pivot_table(
        index=["JobRole"], 
        columns=["Attrition", "JobLevel"], 
        values="MonthlyIncome", 
        aggfunc="mean", 
        observed=False, 
        # fill_value=0
    ).style.background_gradient(
        cmap="RdYlGn", 
        axis="columns"
    ).format(
        "$ {:_.2f}"
    )
)
# Out:
# <style type="text/css">
# #T_7aba0_row0_col0, #T_7aba0_row0_col4, #T_7aba0_row0_col5, #T_7aba0_row0_col9, #T_7aba0_row1_col3, #T_7aba0_row1_col4, #T_7aba0_row1_col6, #T_7aba0_row1_col8, #T_7aba0_row1_col9, #T_7aba0_row2_col3, #T_7aba0_row2_col4, #T_7aba0_row2_col8, #T_7aba0_row2_col9, #T_7aba0_row3_col0, #T_7aba0_row3_col1, #T_7aba0_row3_col5, #T_7aba0_row3_col6, #T_7aba0_row3_col8, #T_7aba0_row4_col0, #T_7aba0_row4_col4, #T_7aba0_row4_col5, #T_7aba0_row4_col8, #T_7aba0_row4_col9, #T_7aba0_row5_col0, #T_7aba0_row5_col1, #T_7aba0_row5_col5, #T_7aba0_row5_col6, #T_7aba0_row5_col7, #T_7aba0_row5_col8, #T_7aba0_row6_col3, #T_7aba0_row6_col4, #T_7aba0_row6_col7, #T_7aba0_row6_col8, #T_7aba0_row6_col9, #T_7aba0_row7_col0, #T_7aba0_row7_col4, #T_7aba0_row7_col5, #T_7aba0_row7_col9, #T_7aba0_row8_col2, #T_7aba0_row8_col3, #T_7aba0_row8_col4, #T_7aba0_row8_col7, #T_7aba0_row8_col8, #T_7aba0_row8_col9 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_7aba0_row0_col1, #T_7aba0_row1_col5, #T_7aba0_row2_col5, #T_7aba0_row3_col2, #T_7aba0_row4_col6, #T_7aba0_row5_col2, #T_7aba0_row6_col5, #T_7aba0_row7_col1, #T_7aba0_row8_col6 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_7aba0_row0_col2 {
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_7aba0_row0_col3, #T_7aba0_row1_col7, #T_7aba0_row2_col2, #T_7aba0_row3_col9, #T_7aba0_row4_col3, #T_7aba0_row5_col9, #T_7aba0_row6_col2, #T_7aba0_row7_col8, #T_7aba0_row8_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_7aba0_row0_col6, #T_7aba0_row8_col5 {
#   background-color: #e14430;
#   color: #f1f1f1;
# }
# #T_7aba0_row0_col7 {
#   background-color: #fee695;
#   color: #000000;
# }
# #T_7aba0_row0_col8 {
#   background-color: #2aa054;
#   color: #f1f1f1;
# }
# #T_7aba0_row1_col0 {
#   background-color: #c01a27;
#   color: #f1f1f1;
# }
# #T_7aba0_row1_col1 {
#   background-color: #fee18d;
#   color: #000000;
# }
# #T_7aba0_row1_col2 {
#   background-color: #249d53;
#   color: #f1f1f1;
# }
# #T_7aba0_row2_col0 {
#   background-color: #c41e27;
#   color: #f1f1f1;
# }
# #T_7aba0_row2_col1 {
#   background-color: #fff6b0;
#   color: #000000;
# }
# #T_7aba0_row2_col6 {
#   background-color: #b9e176;
#   color: #000000;
# }
# #T_7aba0_row2_col7 {
#   background-color: #89cc67;
#   color: #000000;
# }
# #T_7aba0_row3_col3 {
#   background-color: #d5ed88;
#   color: #000000;
# }
# #T_7aba0_row3_col4 {
#   background-color: #0c7f43;
#   color: #f1f1f1;
# }
# #T_7aba0_row3_col7 {
#   background-color: #cc2627;
#   color: #f1f1f1;
# }
# #T_7aba0_row4_col1 {
#   background-color: #c62027;
#   color: #f1f1f1;
# }
# #T_7aba0_row4_col2 {
#   background-color: #fdfebc;
#   color: #000000;
# }
# #T_7aba0_row4_col7 {
#   background-color: #ebf7a3;
#   color: #000000;
# }
# #T_7aba0_row5_col3 {
#   background-color: #e9f6a1;
#   color: #000000;
# }
# #T_7aba0_row5_col4 {
#   background-color: #07753e;
#   color: #f1f1f1;
# }
# #T_7aba0_row6_col0 {
#   background-color: #b10b26;
#   color: #f1f1f1;
# }
# #T_7aba0_row6_col1 {
#   background-color: #fdaf62;
#   color: #000000;
# }
# #T_7aba0_row6_col6 {
#   background-color: #fca55d;
#   color: #000000;
# }
# #T_7aba0_row7_col2 {
#   background-color: #feec9f;
#   color: #000000;
# }
# #T_7aba0_row7_col3 {
#   background-color: #097940;
#   color: #f1f1f1;
# }
# #T_7aba0_row7_col6 {
#   background-color: #b50f26;
#   color: #f1f1f1;
# }
# #T_7aba0_row7_col7 {
#   background-color: #fff0a6;
#   color: #000000;
# }
# #T_7aba0_row8_col0 {
#   background-color: #f8864f;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7aba0">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Attrition</th>
#       <th id="T_7aba0_level0_col0" class="col_heading level0 col0" colspan="5">No</th>
#       <th id="T_7aba0_level0_col5" class="col_heading level0 col5" colspan="5">Yes</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >JobLevel</th>
#       <th id="T_7aba0_level1_col0" class="col_heading level1 col0" >1</th>
#       <th id="T_7aba0_level1_col1" class="col_heading level1 col1" >2</th>
#       <th id="T_7aba0_level1_col2" class="col_heading level1 col2" >3</th>
#       <th id="T_7aba0_level1_col3" class="col_heading level1 col3" >4</th>
#       <th id="T_7aba0_level1_col4" class="col_heading level1 col4" >5</th>
#       <th id="T_7aba0_level1_col5" class="col_heading level1 col5" >1</th>
#       <th id="T_7aba0_level1_col6" class="col_heading level1 col6" >2</th>
#       <th id="T_7aba0_level1_col7" class="col_heading level1 col7" >3</th>
#       <th id="T_7aba0_level1_col8" class="col_heading level1 col8" >4</th>
#       <th id="T_7aba0_level1_col9" class="col_heading level1 col9" >5</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >JobRole</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7aba0_level0_row0" class="row_heading level0 row0" >Healthcare Representative</th>
#       <td id="T_7aba0_row0_col0" class="data row0 col0" >$ nan</td>
#       <td id="T_7aba0_row0_col1" class="data row0 col1" >$ 5_828.28</td>
#       <td id="T_7aba0_row0_col2" class="data row0 col2" >$ 9_426.28</td>
#       <td id="T_7aba0_row0_col3" class="data row0 col3" >$ 13_073.50</td>
#       <td id="T_7aba0_row0_col4" class="data row0 col4" >$ nan</td>
#       <td id="T_7aba0_row0_col5" class="data row0 col5" >$ nan</td>
#       <td id="T_7aba0_row0_col6" class="data row0 col6" >$ 6_792.00</td>
#       <td id="T_7aba0_row0_col7" class="data row0 col7" >$ 8_877.80</td>
#       <td id="T_7aba0_row0_col8" class="data row0 col8" >$ 12_169.00</td>
#       <td id="T_7aba0_row0_col9" class="data row0 col9" >$ nan</td>
#     </tr>
#     <tr>
#       <th id="T_7aba0_level0_row1" class="row_heading level0 row1" >Human Resources</th>
#       <td id="T_7aba0_row1_col0" class="data row1 col0" >$ 2_871.26</td>
#       <td id="T_7aba0_row1_col1" class="data row1 col1" >$ 5_563.46</td>
#       <td id="T_7aba0_row1_col2" class="data row1 col2" >$ 9_326.50</td>
#       <td id="T_7aba0_row1_col3" class="data row1 col3" >$ nan</td>
#       <td id="T_7aba0_row1_col4" class="data row1 col4" >$ nan</td>
#       <td id="T_7aba0_row1_col5" class="data row1 col5" >$ 2_415.70</td>
#       <td id="T_7aba0_row1_col6" class="data row1 col6" >$ nan</td>
#       <td id="T_7aba0_row1_col7" class="data row1 col7" >$ 10_216.00</td>
#       <td id="T_7aba0_row1_col8" class="data row1 col8" >$ nan</td>
#       <td id="T_7aba0_row1_col9" class="data row1 col9" >$ nan</td>
#     </tr>
#     <tr>
#       <th id="T_7aba0_level0_row2" class="row_heading level0 row2" >Laboratory Technician</th>
#       <td id="T_7aba0_row2_col0" class="data row2 col0" >$ 2_921.71</td>
#       <td id="T_7aba0_row2_col1" class="data row2 col1" >$ 4_394.00</td>
#       <td id="T_7aba0_row2_col2" class="data row2 col2" >$ 6_306.50</td>
#       <td id="T_7aba0_row2_col3" class="data row2 col3" >$ nan</td>
#       <td id="T_7aba0_row2_col4" class="data row2 col4" >$ nan</td>
#       <td id="T_7aba0_row2_col5" class="data row2 col5" >$ 2_682.00</td>
#       <td id="T_7aba0_row2_col6" class="data row2 col6" >$ 5_084.20</td>
#       <td id="T_7aba0_row2_col7" class="data row2 col7" >$ 5_381.00</td>
#       <td id="T_7aba0_row2_col8" class="data row2 col8" >$ nan</td>
#       <td id="T_7aba0_row2_col9" class="data row2 col9" >$ nan</td>
#     </tr>
#     <tr>
#       <th id="T_7aba0_level0_row3" class="row_heading level0 row3" >Manager</th>
#       <td id="T_7aba0_row3_col0" class="data row3 col0" >$ nan</td>
#       <td id="T_7aba0_row3_col1" class="data row3 col1" >$ nan</td>
#       <td id="T_7aba0_row3_col2" class="data row3 col2" >$ 12_133.70</td>
#       <td id="T_7aba0_row3_col3" class="data row3 col3" >$ 16_613.28</td>
#       <td id="T_7aba0_row3_col4" class="data row3 col4" >$ 19_159.58</td>
#       <td id="T_7aba0_row3_col5" class="data row3 col5" >$ nan</td>
#       <td id="T_7aba0_row3_col6" class="data row3 col6" >$ nan</td>
#       <t

# %%
display(
    df_colunas_removidas.pivot_table(
        index=["JobRole", "JobLevel"], 
        columns=["Attrition"], 
        values="MonthlyIncome", 
        aggfunc="mean", 
        observed=False, 
        # fill_value=0
    ).style.background_gradient(
        cmap="Greens", 
        axis="columns"
    ).format(
        "$ {:_.2f}"
    )
)
# Out:
# <style type="text/css">
# #T_2ce73_row0_col0, #T_2ce73_row1_col1, #T_2ce73_row2_col1, #T_2ce73_row3_col1, #T_2ce73_row4_col0, #T_2ce73_row4_col1, #T_2ce73_row5_col0, #T_2ce73_row6_col1, #T_2ce73_row7_col0, #T_2ce73_row8_col1, #T_2ce73_row9_col0, #T_2ce73_row10_col0, #T_2ce73_row10_col1, #T_2ce73_row11_col0, #T_2ce73_row12_col1, #T_2ce73_row13_col0, #T_2ce73_row14_col0, #T_2ce73_row14_col1, #T_2ce73_row15_col0, #T_2ce73_row15_col1, #T_2ce73_row16_col0, #T_2ce73_row16_col1, #T_2ce73_row17_col0, #T_2ce73_row18_col1, #T_2ce73_row19_col1, #T_2ce73_row20_col0, #T_2ce73_row20_col1, #T_2ce73_row21_col0, #T_2ce73_row22_col0, #T_2ce73_row23_col0, #T_2ce73_row24_col1, #T_2ce73_row25_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_2ce73_row0_col1, #T_2ce73_row1_col0, #T_2ce73_row2_col0, #T_2ce73_row3_col0, #T_2ce73_row5_col1, #T_2ce73_row6_col0, #T_2ce73_row7_col1, #T_2ce73_row8_col0, #T_2ce73_row9_col1, #T_2ce73_row11_col1, #T_2ce73_row12_col0, #T_2ce73_row13_col1, #T_2ce73_row17_col1, #T_2ce73_row18_col0, #T_2ce73_row19_col0, #T_2ce73_row21_col1, #T_2ce73_row22_col1, #T_2ce73_row23_col1, #T_2ce73_row24_col0, #T_2ce73_row25_col0 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2ce73">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Attrition</th>
#       <th id="T_2ce73_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_2ce73_level0_col1" class="col_heading level0 col1" >Yes</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >JobRole</th>
#       <th class="index_name level1" >JobLevel</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2ce73_level0_row0" class="row_heading level0 row0" rowspan="3">Healthcare Representative</th>
#       <th id="T_2ce73_level1_row0" class="row_heading level1 row0" >2</th>
#       <td id="T_2ce73_row0_col0" class="data row0 col0" >$ 5_828.28</td>
#       <td id="T_2ce73_row0_col1" class="data row0 col1" >$ 6_792.00</td>
#     </tr>
#     <tr>
#       <th id="T_2ce73_level1_row1" class="row_heading level1 row1" >3</th>
#       <td id="T_2ce73_row1_col0" class="data row1 col0" >$ 9_426.28</td>
#       <td id="T_2ce73_row1_col1" class="data row1 col1" >$ 8_877.80</td>
#     </tr>
#     <tr>
#       <th id="T_2ce73_level1_row2" class="row_heading level1 row2" >4</th>
#       <td id="T_2ce73_row2_col0" class="data row2 col0" >$ 13_073.50</td>
#       <td id="T_2ce73_row2_col1" class="data row2 col1" >$ 12_169.00</td>
#     </tr>
#     <tr>
#       <th id="T_2ce73_level0_row3" class="row_heading level0 row3" rowspan="3">Human Resources</th>
#       <th id="T_2ce73_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_2ce73_row3_col0" class="data row3 col0" >$ 2_871.26</td>
#       <td id="T_2ce73_row3_col1" class="data row3 col1" >$ 2_415.70</td>
#     </tr>
#     <tr>
#       <th id="T_2ce73_level1_row4" class="row_heading level1 row4" >2</th>
#       <td id="T_2ce73_row4_col0" class="data row4 col0" >$ 5_563.46</td>
#       <td id="T_2ce73_row4_col1" class="data row4 col1" >$ nan</td>
#     </tr>
#     <tr>
#       <th id="T_2ce73_level1_row5" class="row_heading level1 row5" >3</th>
#       <td id="T_2ce73_row5_col0" class="data row5 col0" >$ 9_326.50</td>
#       <td id="T_2ce73_row5_col1" class="data row5 col1" >$ 10_216.00</td>
#     </tr>
#     <tr>
#       <th id="T_2ce73_level0_row6" class="row_heading level0 row6" rowspan="3">Laboratory Technician</th>
#       <th id="T_2ce73_level1_row6" class="row_heading level1 row6" >1</th>
#       <td id="T_2ce73_row6_col0" class="data row6 col0" >$ 2_921.71</td>
#       <td id="T_2ce73_row6_col1" class="data row6 col1" >$ 2_682.00</td>
#     </tr>
#     <tr>
#       <th id="T_2ce73_level1_row7" class="row_heading level1 row7" >2</th>
#       <td id="T_2ce73_row7_col0" class="data row7 col0" >$ 4_394.00</td>
#       <td id="T_2ce73_row7_col1" class="data row7 col1" >$ 5_084.20</td>
#     </tr>
#     <tr>
#       <th id="T_2ce73_level1_row8" class="row_heading level1 row8" >3</th>
#       <td id="T_2ce73_row8_col0" class="data row8 col0" >$ 6_306.50</td>
#       <td id="T_2ce73_row8_col1" class="data row8 col1" >$ 5_381.00</td>
#     </tr>
#     <tr>
#       <th id="T_2ce73_level0_row9" class="row_heading level0 row9" rowspan="3">Manager</th>
#       <th id="T_2ce73_level1_row9" class="row_heading level1 row9" >3</th>
#       <td id="T_2ce73_row9_col0" class="data row9 col0" >$ 12_133.70</td>
#       <td id="T_2ce73_row9_col1" class="data row9 col1" >$ 12_729.50</td>
#     </tr>
#     <tr>
#       <th id="T_2ce73_level1_row10" class="row_heading level1 row10" >4</th>
#       <td id="T_2ce73_row10_col0" class="data row10 col0" >$ 16_613.28</td>
#       <td id="T_2ce73_row10_col1" class="data row10 col1" >$ nan</td>
#     </tr>
#     <tr>
#       <th id="T_2ce73_level1_row11" class="row_heading level1 row11" >5</th>
#       <td id="T_2ce73_row11_col0" class="data row11 col0" >$ 19_159.58</td>
#       <td id="T_2ce73_row11_col1" class="data row11 col1" >$ 19_509.33</td>
#     </tr>
#     <tr>
#       <th id="T_2ce73_level0_row12" class="row_heading level0 row12" rowspan="3">Manufacturing Director</th>
#       <th id="T_2ce73_level1_row12" class="row_heading level1 row12" >2</th>
#       <td id="T_2ce73_row12_col0" class="data row12 col0" >$ 5_644.87</td>
#       <td id="T_2ce73_row12_col1" class="data row12 col1" >$ 5_066.80</td>
#     </tr>
#     <tr>
#       <th id="T_2ce73_level1_row13" class="row_heading level1 row13" >3</th>
#       <td id="T_2ce73_row13_col0" class="data row13 col0" >$ 9_262.40</td>
#       <td id="T_2ce73_row13_col1" class="data row13 col1" >$ 9_664.20</td>
#     </tr>
#     <tr>
#       <th id="T_2ce73_level1_row14" class="row_heading level1 row14" >4</th>
#       <td id="T_2ce73_row14_col0" class="data row14 col0" >$ 13_383.00</td>
#       <td id="T_2ce73_row14_col1" class="data row14 col1" >$ nan</td>
#     </tr>
#     <tr>
#       <th id="T_2ce73_level0_row15" class="row_heading level0 row15" rowspan="3">Research Director</th>
#       <th id="T_2ce73_level1_row15" class="row_heading level1 row15" >3</th>
#       <td id="T_2ce73_row15_col0" class="data row15 col0" >$ 12_721.57</td>
#       <td id="T_2ce73_row15_col1" class="data row15 col1" >$ nan</td>
#     </tr>
#     <tr>
#       <th id="T_2ce73_level1_row16" class="row_heading level1 row16" >4</th>
#       <td id="T_2ce73_row16_col0" class="data row16 col0" >$ 16_429.04</td>
#       <td id="T_2ce73_row16_col1" class="data row16 col1" >$ nan</td>
#     </tr>
#     <tr>
#       <th id="T_2ce73_level1_row17" class="row_heading level1 row17" >5</th>
#       <td id="T_2ce73_row17_col0" class="data row17 col0" >$ 19_188.92</td>
#       <td id="T_2ce73_row17_col1" class="data row17 col1" >$ 19_395.50</td>
#     </tr>
#     <tr>
#       <th id="T_2ce73_level0_row18" class="row_heading level0 row18" rowspan="3">Research Scientist</th>
#       <th id="T_2ce73_level1_row18" class="row_heading level1 row18" >1</th>
#       <td id="T_2ce73_row18_col0" class="data row18 col0" >$ 2_859.46</td>
#       <td id="T_2ce73_row18_col1" class="data row18 col1" >$ 2_694.07</td>
#     </tr>
#     <tr>
#       <th id="T_2ce73_level1_row19" class="row_heading level1 row19" >2</th>
#       <td id="T_2ce73_row19_col0" class="data row19 col0" >$ 4_822.35</td>
#       <td id="T_2ce73_row19_col1" class="data row19 col1" >$ 4_724.50</td>
#     </tr>
#     <tr>
#       <th id="T_2ce73_level1_row20" class="row_heading level1 row20" >3</th>
#       <td id="T_2ce73_row20_col0" class="data row20 col0" >$ 9_724.00</td>
#       <td id="T_2ce73_row20_col1" class="data row20 col1" >$ nan</td>
#     </tr>
#     <tr>
#       <th id="T_2ce73_level0_row21" class="row_heading level0 row21" rowspan="3">Sales Executive</th>
#       <th id="T_2ce73_level1_row21" class="row_heading level1 row21" >2</th>
#       <td id="T_2ce73_row21_col0" class="data row21 col0" >$ 5_760.22</td>
#       <td id="T_2ce73_row21_col1" class="data row21 col1" >$ 6_023.42</td>
#     </tr>
#     <tr>
#       <th id="T_2ce73_level1_row22" class="row_heading level1 row22" >3</th>
#       <td id="T_2ce73_row22_c

# %%
with pd.option_context("float_format", "$ {:_.2f}".format):
    display(
        df_colunas_removidas.pivot_table(
            index=["JobRole", "JobLevel"], 
            columns="Attrition", 
            values="MonthlyIncome", 
            aggfunc=["mean", "size"], 
            observed=False, 
        ).dropna(
            how="all", 
            subset=[("mean", "No"), ("mean", "Yes")]
        )
    )
# Out:
#                                           mean             size
# Attrition                                   No         Yes   No Yes
# JobRole                   JobLevel
# Healthcare Representative 2         $ 5_828.28  $ 6_792.00   75   3
#                           3         $ 9_426.28  $ 8_877.80   39   5
#                           4        $ 13_073.50 $ 12_169.00    8   1
# Human Resources           1         $ 2_871.26  $ 2_415.70   23  10
#                           2         $ 5_563.46         NaN   13   0
#                           3         $ 9_326.50 $ 10_216.00    4   2
# Laboratory Technician     1         $ 2_921.71  $ 2_682.00  144  56
#                           2         $ 4_394.00  $ 5_084.20   51   5
#                           3         $ 6_306.50  $ 5_381.00    2   1
# Manager                   3        $ 12_133.70 $ 12_729.50   10   2
#                           4        $ 16_613.28         NaN   47   0
#                           5        $ 19_159.58 $ 19_509.33   40   3
# Manufacturing Director    2         $ 5_644.87  $ 5_066.80   85   5
#                           3         $ 9_262.40  $ 9_664.20   40   5
#                           4        $ 13_383.00         NaN   10   0
# Research Director         3        $ 12_721.57         NaN   28   0
#                           4        $ 16_429.04         NaN   26   0
#                           5        $ 19_188.92 $ 19_395.50   24   2
# Research Scientist        1         $ 2_859.46  $ 2_694.07  189  45
#                           2         $ 4_822.35  $ 4_724.50   55   2
#                           3         $ 9_724.00         NaN    1   0
# Sales Executive           2         $ 5_760.22  $ 6_023.42  197  36
#                           3         $ 9_103.66  $ 9_202.76   62  17
#                           4        $ 13_125.20 $ 13_395.75   10   4
# Sales Representative      1         $ 2_603.66  $ 2_373.44   44  32
#                           2         $ 4_226.83  $ 2_086.00    6   1

# %%
display(
    pd.crosstab(
        [df_colunas_removidas["JobRole"], df_colunas_removidas["JobLevel"]], 
        df_colunas_removidas["Attrition"], 
        normalize="index",
    ).style.background_gradient(
        cmap="winter", 
        axis="columns",
        vmin=0,
        vmax=1,
    ).format(
        "{:_.2%}"
    )
)
# Out:
# <style type="text/css">
# #T_b1240_row0_col0 {
#   background-color: #00f684;
#   color: #000000;
# }
# #T_b1240_row0_col1 {
#   background-color: #0009fa;
#   color: #f1f1f1;
# }
# #T_b1240_row1_col0 {
#   background-color: #00e28e;
#   color: #000000;
# }
# #T_b1240_row1_col1 {
#   background-color: #001df0;
#   color: #f1f1f1;
# }
# #T_b1240_row2_col0, #T_b1240_row13_col0 {
#   background-color: #00e38e;
#   color: #000000;
# }
# #T_b1240_row2_col1, #T_b1240_row13_col1 {
#   background-color: #001cf1;
#   color: #f1f1f1;
# }
# #T_b1240_row3_col0 {
#   background-color: #00b2a6;
#   color: #f1f1f1;
# }
# #T_b1240_row3_col1 {
#   background-color: #004dd8;
#   color: #f1f1f1;
# }
# #T_b1240_row4_col0, #T_b1240_row10_col0, #T_b1240_row14_col0, #T_b1240_row15_col0, #T_b1240_row16_col0, #T_b1240_row20_col0 {
#   background-color: #00ff80;
#   color: #000000;
# }
# #T_b1240_row4_col1, #T_b1240_row10_col1, #T_b1240_row14_col1, #T_b1240_row15_col1, #T_b1240_row16_col1, #T_b1240_row20_col1 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# #T_b1240_row5_col0, #T_b1240_row8_col0 {
#   background-color: #00aaaa;
#   color: #f1f1f1;
# }
# #T_b1240_row5_col1, #T_b1240_row8_col1 {
#   background-color: #0055d4;
#   color: #f1f1f1;
# }
# #T_b1240_row6_col0 {
#   background-color: #00b8a3;
#   color: #f1f1f1;
# }
# #T_b1240_row6_col1 {
#   background-color: #0047dc;
#   color: #f1f1f1;
# }
# #T_b1240_row7_col0 {
#   background-color: #00e98b;
#   color: #000000;
# }
# #T_b1240_row7_col1 {
#   background-color: #0016f4;
#   color: #f1f1f1;
# }
# #T_b1240_row9_col0 {
#   background-color: #00d594;
#   color: #000000;
# }
# #T_b1240_row9_col1 {
#   background-color: #002aea;
#   color: #f1f1f1;
# }
# #T_b1240_row11_col0 {
#   background-color: #00ee88;
#   color: #000000;
# }
# #T_b1240_row11_col1 {
#   background-color: #0011f6;
#   color: #f1f1f1;
# }
# #T_b1240_row12_col0 {
#   background-color: #00f186;
#   color: #000000;
# }
# #T_b1240_row12_col1 {
#   background-color: #000ef8;
#   color: #f1f1f1;
# }
# #T_b1240_row17_col0 {
#   background-color: #00ec89;
#   color: #000000;
# }
# #T_b1240_row17_col1 {
#   background-color: #0013f6;
#   color: #f1f1f1;
# }
# #T_b1240_row18_col0 {
#   background-color: #00ce98;
#   color: #000000;
# }
# #T_b1240_row18_col1 {
#   background-color: #0031e6;
#   color: #f1f1f1;
# }
# #T_b1240_row19_col0 {
#   background-color: #00f784;
#   color: #000000;
# }
# #T_b1240_row19_col1 {
#   background-color: #0008fb;
#   color: #f1f1f1;
# }
# #T_b1240_row21_col0 {
#   background-color: #00d893;
#   color: #000000;
# }
# #T_b1240_row21_col1 {
#   background-color: #0027ec;
#   color: #f1f1f1;
# }
# #T_b1240_row22_col0 {
#   background-color: #00c89b;
#   color: #000000;
# }
# #T_b1240_row22_col1 {
#   background-color: #0037e3;
#   color: #f1f1f1;
# }
# #T_b1240_row23_col0 {
#   background-color: #00b6a4;
#   color: #f1f1f1;
# }
# #T_b1240_row23_col1 {
#   background-color: #0049db;
#   color: #f1f1f1;
# }
# #T_b1240_row24_col0 {
#   background-color: #0094b5;
#   color: #f1f1f1;
# }
# #T_b1240_row24_col1 {
#   background-color: #006bca;
#   color: #f1f1f1;
# }
# #T_b1240_row25_col0 {
#   background-color: #00db92;
#   color: #000000;
# }
# #T_b1240_row25_col1 {
#   background-color: #0024ed;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b1240">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Attrition</th>
#       <th id="T_b1240_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_b1240_level0_col1" class="col_heading level0 col1" >Yes</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >JobRole</th>
#       <th class="index_name level1" >JobLevel</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b1240_level0_row0" class="row_heading level0 row0" rowspan="3">Healthcare Representative</th>
#       <th id="T_b1240_level1_row0" class="row_heading level1 row0" >2</th>
#       <td id="T_b1240_row0_col0" class="data row0 col0" >96.15%</td>
#       <td id="T_b1240_row0_col1" class="data row0 col1" >3.85%</td>
#     </tr>
#     <tr>
#       <th id="T_b1240_level1_row1" class="row_heading level1 row1" >3</th>
#       <td id="T_b1240_row1_col0" class="data row1 col0" >88.64%</td>
#       <td id="T_b1240_row1_col1" class="data row1 col1" >11.36%</td>
#     </tr>
#     <tr>
#       <th id="T_b1240_level1_row2" class="row_heading level1 row2" >4</th>
#       <td id="T_b1240_row2_col0" class="data row2 col0" >88.89%</td>
#       <td id="T_b1240_row2_col1" class="data row2 col1" >11.11%</td>
#     </tr>
#     <tr>
#       <th id="T_b1240_level0_row3" class="row_heading level0 row3" rowspan="3">Human Resources</th>
#       <th id="T_b1240_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_b1240_row3_col0" class="data row3 col0" >69.70%</td>
#       <td id="T_b1240_row3_col1" class="data row3 col1" >30.30%</td>
#     </tr>
#     <tr>
#       <th id="T_b1240_level1_row4" class="row_heading level1 row4" >2</th>
#       <td id="T_b1240_row4_col0" class="data row4 col0" >100.00%</td>
#       <td id="T_b1240_row4_col1" class="data row4 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_b1240_level1_row5" class="row_heading level1 row5" >3</th>
#       <td id="T_b1240_row5_col0" class="data row5 col0" >66.67%</td>
#       <td id="T_b1240_row5_col1" class="data row5 col1" >33.33%</td>
#     </tr>
#     <tr>
#       <th id="T_b1240_level0_row6" class="row_heading level0 row6" rowspan="3">Laboratory Technician</th>
#       <th id="T_b1240_level1_row6" class="row_heading level1 row6" >1</th>
#       <td id="T_b1240_row6_col0" class="data row6 col0" >72.00%</td>
#       <td id="T_b1240_row6_col1" class="data row6 col1" >28.00%</td>
#     </tr>
#     <tr>
#       <th id="T_b1240_level1_row7" class="row_heading level1 row7" >2</th>
#       <td id="T_b1240_row7_col0" class="data row7 col0" >91.07%</td>
#       <td id="T_b1240_row7_col1" class="data row7 col1" >8.93%</td>
#     </tr>
#     <tr>
#       <th id="T_b1240_level1_row8" class="row_heading level1 row8" >3</th>
#       <td id="T_b1240_row8_col0" class="data row8 col0" >66.67%</td>
#       <td id="T_b1240_row8_col1" class="data row8 col1" >33.33%</td>
#     </tr>
#     <tr>
#       <th id="T_b1240_level0_row9" class="row_heading level0 row9" rowspan="3">Manager</th>
#       <th id="T_b1240_level1_row9" class="row_heading level1 row9" >3</th>
#       <td id="T_b1240_row9_col0" class="data row9 col0" >83.33%</td>
#       <td id="T_b1240_row9_col1" class="data row9 col1" >16.67%</td>
#     </tr>
#     <tr>
#       <th id="T_b1240_level1_row10" class="row_heading level1 row10" >4</th>
#       <td id="T_b1240_row10_col0" class="data row10 col0" >100.00%</td>
#       <td id="T_b1240_row10_col1" class="data row10 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_b1240_level1_row11" class="row_heading level1 row11" >5</th>
#       <td id="T_b1240_row11_col0" class="data row11 col0" >93.02%</td>
#       <td id="T_b1240_row11_col1" class="data row11 col1" >6.98%</td>
#     </tr>
#     <tr>
#       <th id="T_b1240_level0_row12" class="row_heading level0 row12" rowspan="3">Manufacturing Director</th>
#       <th id="T_b1240_level1_row12" class="row_heading level1 row12" >2</th>
#       <td id="T_b1240_row12_col0" class="data row12 col0" >94.44%</td>
#       <td id="T_b1240_row12_col1" class="data row12 col1" >5.56%</td>
#     </tr>
#     <tr>
#       <th id="T_b1240_level1_row13" class="row_heading level1 row13" >3</th>
#       <td id="T_b1240_row13_col0" class="data row13 col0" >88.89%</td>
#       <td id="T_b1240_row13_col1" class="data row13 col1" >11.11%</td>
#     </tr>
#     <tr>
#       <th id="T_b1240_level1_row14" class="row_heading level1 row14" >4</th>
#       <td id="T_b1240_row14_col0" class="data row14 col0" >100.00%</td>
#       <td id="T_b1240_row14_col1" class="data row14 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_b1240_level0_row15" class="row_heading level0 row15" rowspan="3">Research Director</th>
#       <th id="T_b1240_level1_row15" class="row_heading level1 row15" >3</th>
#       <td id="T_b1240_row15_col0" class="data row15 col0" >100.00%</td>
#       <td id="T_b1240_row15_col1" class="data row15 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_b1240_level1_row16" class="row_heading level1 row16" >4</th>
#       <td id="T_b1240_row16

# %% [markdown]
# * Agrupamentos: gênero por departamento

# %%
display(
    df_colunas_removidas.pivot_table(
        index=["Department", "Gender"], 
        columns=["Attrition"], 
        aggfunc="size", 
        observed=False
    )
)

display(
    pd.crosstab(
        [df_colunas_removidas["Department"], df_colunas_removidas["Gender"]], 
        [df_colunas_removidas["Attrition"]], 
        margins=True, 
        margins_name="Total",
    ).style.background_gradient(
        cmap="RdYlGn",
        axis="columns",
        vmin=0,
        vmax=200
    )
)

display(
    pd.crosstab(
        [df_colunas_removidas["Department"], df_colunas_removidas["Gender"]], 
        [df_colunas_removidas["Attrition"]], 
        margins=True, 
        margins_name="Total",
        normalize="index",
    ).style.background_gradient(
        cmap="RdYlGn",
        axis="columns",
        vmin=0,
        vmax=1
    ).format(
        "{:.2%}"
    )
)
# Out:
# Attrition                       No  Yes
# Department             Gender
# Human Resources        Female   14    6
#                        Male     37    6
# Research & Development Female  336   43
#                        Male    492   90
# Sales                  Female  151   38
#                        Male    203   54
# <style type="text/css">
# #T_01f3d_row0_col0 {
#   background-color: #c62027;
#   color: #f1f1f1;
# }
# #T_01f3d_row0_col1, #T_01f3d_row1_col1 {
#   background-color: #b30d26;
#   color: #f1f1f1;
# }
# #T_01f3d_row0_col2 {
#   background-color: #d62f27;
#   color: #f1f1f1;
# }
# #T_01f3d_row1_col0 {
#   background-color: #ef633f;
#   color: #f1f1f1;
# }
# #T_01f3d_row1_col2, #T_01f3d_row2_col1 {
#   background-color: #f57748;
#   color: #f1f1f1;
# }
# #T_01f3d_row2_col0, #T_01f3d_row2_col2, #T_01f3d_row3_col0, #T_01f3d_row3_col2, #T_01f3d_row5_col0, #T_01f3d_row5_col2, #T_01f3d_row6_col0, #T_01f3d_row6_col1, #T_01f3d_row6_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_01f3d_row3_col1 {
#   background-color: #fff0a6;
#   color: #000000;
# }
# #T_01f3d_row4_col0 {
#   background-color: #82c966;
#   color: #000000;
# }
# #T_01f3d_row4_col1 {
#   background-color: #f16640;
#   color: #f1f1f1;
# }
# #T_01f3d_row4_col2 {
#   background-color: #0e8245;
#   color: #f1f1f1;
# }
# #T_01f3d_row5_col1 {
#   background-color: #fa9b58;
#   color: #000000;
# }
# </style>
# <table id="T_01f3d">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Attrition</th>
#       <th id="T_01f3d_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_01f3d_level0_col1" class="col_heading level0 col1" >Yes</th>
#       <th id="T_01f3d_level0_col2" class="col_heading level0 col2" >Total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Department</th>
#       <th class="index_name level1" >Gender</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_01f3d_level0_row0" class="row_heading level0 row0" rowspan="2">Human Resources</th>
#       <th id="T_01f3d_level1_row0" class="row_heading level1 row0" >Female</th>
#       <td id="T_01f3d_row0_col0" class="data row0 col0" >14</td>
#       <td id="T_01f3d_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_01f3d_row0_col2" class="data row0 col2" >20</td>
#     </tr>
#     <tr>
#       <th id="T_01f3d_level1_row1" class="row_heading level1 row1" >Male</th>
#       <td id="T_01f3d_row1_col0" class="data row1 col0" >37</td>
#       <td id="T_01f3d_row1_col1" class="data row1 col1" >6</td>
#       <td id="T_01f3d_row1_col2" class="data row1 col2" >43</td>
#     </tr>
#     <tr>
#       <th id="T_01f3d_level0_row2" class="row_heading level0 row2" rowspan="2">Research & Development</th>
#       <th id="T_01f3d_level1_row2" class="row_heading level1 row2" >Female</th>
#       <td id="T_01f3d_row2_col0" class="data row2 col0" >336</td>
#       <td id="T_01f3d_row2_col1" class="data row2 col1" >43</td>
#       <td id="T_01f3d_row2_col2" class="data row2 col2" >379</td>
#     </tr>
#     <tr>
#       <th id="T_01f3d_level1_row3" class="row_heading level1 row3" >Male</th>
#       <td id="T_01f3d_row3_col0" class="data row3 col0" >492</td>
#       <td id="T_01f3d_row3_col1" class="data row3 col1" >90</td>
#       <td id="T_01f3d_row3_col2" class="data row3 col2" >582</td>
#     </tr>
#     <tr>
#       <th id="T_01f3d_level0_row4" class="row_heading level0 row4" rowspan="2">Sales</th>
#       <th id="T_01f3d_level1_row4" class="row_heading level1 row4" >Female</th>
#       <td id="T_01f3d_row4_col0" class="data row4 col0" >151</td>
#       <td id="T_01f3d_row4_col1" class="data row4 col1" >38</td>
#       <td id="T_01f3d_row4_col2" class="data row4 col2" >189</td>
#     </tr>
#     <tr>
#       <th id="T_01f3d_level1_row5" class="row_heading level1 row5" >Male</th>
#       <td id="T_01f3d_row5_col0" class="data row5 col0" >203</td>
#       <td id="T_01f3d_row5_col1" class="data row5 col1" >54</td>
#       <td id="T_01f3d_row5_col2" class="data row5 col2" >257</td>
#     </tr>
#     <tr>
#       <th id="T_01f3d_level0_row6" class="row_heading level0 row6" >Total</th>
#       <th id="T_01f3d_level1_row6" class="row_heading level1 row6" ></th>
#       <td id="T_01f3d_row6_col0" class="data row6 col0" >1233</td>
#       <td id="T_01f3d_row6_col1" class="data row6 col1" >237</td>
#       <td id="T_01f3d_row6_col2" class="data row6 col2" >1470</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_a9014_row0_col0 {
#   background-color: #a5d86a;
#   color: #000000;
# }
# #T_a9014_row0_col1 {
#   background-color: #fdad60;
#   color: #000000;
# }
# #T_a9014_row1_col0 {
#   background-color: #36a657;
#   color: #f1f1f1;
# }
# #T_a9014_row1_col1 {
#   background-color: #e24731;
#   color: #f1f1f1;
# }
# #T_a9014_row2_col0 {
#   background-color: #249d53;
#   color: #f1f1f1;
# }
# #T_a9014_row2_col1 {
#   background-color: #db382b;
#   color: #f1f1f1;
# }
# #T_a9014_row3_col0 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_a9014_row3_col1 {
#   background-color: #e65036;
#   color: #f1f1f1;
# }
# #T_a9014_row4_col0 {
#   background-color: #66bd63;
#   color: #f1f1f1;
# }
# #T_a9014_row4_col1 {
#   background-color: #f46d43;
#   color: #f1f1f1;
# }
# #T_a9014_row5_col0 {
#   background-color: #6bbf64;
#   color: #000000;
# }
# #T_a9014_row5_col1 {
#   background-color: #f57245;
#   color: #f1f1f1;
# }
# #T_a9014_row6_col0 {
#   background-color: #48ae5c;
#   color: #f1f1f1;
# }
# #T_a9014_row6_col1 {
#   background-color: #e95538;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a9014">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Attrition</th>
#       <th id="T_a9014_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_a9014_level0_col1" class="col_heading level0 col1" >Yes</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Department</th>
#       <th class="index_name level1" >Gender</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a9014_level0_row0" class="row_heading level0 row0" rowspan="2">Human Resources</th>
#       <th id="T_a9014_level1_row0" class="row_heading level1 row0" >Female</th>
#       <td id="T_a9014_row0_col0" class="data row0 col0" >70.00%</td>
#       <td id="T_a9014_row0_col1" class="data row0 col1" >30.00%</td>
#     </tr>
#     <tr>
#       <th id="T_a9014_level1_row1" class="row_heading level1 row1" >Male</th>
#       <td id="T_a9014_row1_col0" class="data row1 col0" >86.05%</td>
#       <td id="T_a9014_row1_col1" class="data row1 col1" >13.95%</td>
#     </tr>
#     <tr>
#       <th id="T_a9014_level0_row2" class="row_heading level0 row2" rowspan="2">Research & Development</th>
#       <th id="T_a9014_level1_row2" class="row_heading level1 row2" >Female</th>
#       <td id="T_a9014_row2_col0" class="data row2 col0" >88.65%</td>
#       <td id="T_a9014_row2_col1" class="data row2 col1" >11.35%</td>
#     </tr>
#     <tr>
#       <th id="T_a9014_level1_row3" class="row_heading level1 row3" >Male</th>
#       <td id="T_a9014_row3_col0" class="data row3 col0" >84.54%</td>
#       <td id="T_a9014_row3_col1" class="data row3 col1" >15.46%</td>
#     </tr>
#     <tr>
#       <th id="T_a9014_level0_row4" class="row_heading level0 row4" rowspan="2">Sales</th>
#       <th id="T_a9014_level1_row4" class="row_heading level1 row4" >Female</th>
#       <td id="T_a9014_row4_col0" class="data row4 col0" >79.89%</td>
#       <td id="T_a9014_row4_col1" class="data row4 col1" >20.11%</td>
#     </tr>
#     <tr>
#       <th id="T_a9014_level1_row5" class="row_heading level1 row5" >Male</th>
#       <td id="T_a9014_row5_col0" class="data row5 col0" >78.99%</td>
#       <td id="T_a9014_row5_col1" class="data row5 col1" >21.01%</td>
#     </tr>
#     <tr>
#       <th id="T_a9014_level0_row6" class="row_heading level0 row6" >Total</th>
#       <th id="T_a9014_level1_row6" class="row_heading level1 row6" ></th>
#       <td id="T_a9014_row6_col0" class="data row6 col0" >83.88%</td>
#       <td id="T_a9014_row6_col1" class="data row6 col1" >16.12%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# * Agrupamentos: gênero por cargo

# %%
display(
    df_colunas_removidas.pivot_table(
        index="JobRole", 
        columns=["Attrition", "Gender"], 
        aggfunc="size",
        observed=True,
    )
)


display(
    pd.crosstab(
        [df_colunas_removidas["JobRole"]], 
        [df_colunas_removidas["Attrition"], df_colunas_removidas["Gender"]], 
        margins=True, 
        margins_name="Total",
    ).style.background_gradient(
        cmap="RdYlGn",
        axis="columns",
        vmin=0,
        vmax=200
    )
)

display(
    pd.crosstab(
        [df_colunas_removidas["JobRole"]], 
        [df_colunas_removidas["Attrition"], df_colunas_removidas["Gender"]], 
        margins=True, 
        margins_name="Total",
        normalize="index",
    ).style.background_gradient(
        cmap="RdYlGn",
        axis="columns",
        vmin=0,
        vmax=1
    ).format(
        "{:.2%}"
    )
)
# Out:
# Attrition                     No         Yes
# Gender                    Female Male Female Male
# JobRole
# Healthcare Representative     46   76      5    4
# Human Resources               10   30      6    6
# Laboratory Technician         69  128     16   46
# Manager                       45   52      2    3
# Manufacturing Director        68   67      4    6
# Research Director             32   46      1    1
# Research Scientist            97  148     17   30
# Sales Executive              112  157     20   37
# Sales Representative          22   28     16   17
# <style type="text/css">
# #T_a51d6_row0_col0, #T_a51d6_row2_col3, #T_a51d6_row5_col1 {
#   background-color: #f67f4b;
#   color: #f1f1f1;
# }
# #T_a51d6_row0_col1 {
#   background-color: #fed683;
#   color: #000000;
# }
# #T_a51d6_row0_col2 {
#   background-color: #b10b26;
#   color: #f1f1f1;
# }
# #T_a51d6_row0_col3, #T_a51d6_row4_col2 {
#   background-color: #af0926;
#   color: #f1f1f1;
# }
# #T_a51d6_row0_col4 {
#   background-color: #bde379;
#   color: #000000;
# }
# #T_a51d6_row1_col0 {
#   background-color: #bd1726;
#   color: #f1f1f1;
# }
# #T_a51d6_row1_col1, #T_a51d6_row6_col3 {
#   background-color: #e54e35;
#   color: #f1f1f1;
# }
# #T_a51d6_row1_col2, #T_a51d6_row1_col3, #T_a51d6_row4_col3 {
#   background-color: #b30d26;
#   color: #f1f1f1;
# }
# #T_a51d6_row1_col4, #T_a51d6_row3_col1 {
#   background-color: #f99355;
#   color: #000000;
# }
# #T_a51d6_row2_col0 {
#   background-color: #fdc574;
#   color: #000000;
# }
# #T_a51d6_row2_col1 {
#   background-color: #c5e67e;
#   color: #000000;
# }
# #T_a51d6_row2_col2, #T_a51d6_row8_col2 {
#   background-color: #cc2627;
#   color: #f1f1f1;
# }
# #T_a51d6_row2_col4, #T_a51d6_row6_col4, #T_a51d6_row7_col4, #T_a51d6_row9_col0, #T_a51d6_row9_col1, #T_a51d6_row9_col4 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_a51d6_row3_col0 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_a51d6_row3_col2 {
#   background-color: #a90426;
#   color: #f1f1f1;
# }
# #T_a51d6_row3_col3 {
#   background-color: #ab0626;
#   color: #f1f1f1;
# }
# #T_a51d6_row3_col4 {
#   background-color: #fbfdba;
#   color: #000000;
# }
# #T_a51d6_row4_col0 {
#   background-color: #fdc372;
#   color: #000000;
# }
# #T_a51d6_row4_col1 {
#   background-color: #fdbf6f;
#   color: #000000;
# }
# #T_a51d6_row4_col4 {
#   background-color: #96d268;
#   color: #000000;
# }
# #T_a51d6_row5_col0 {
#   background-color: #e75337;
#   color: #f1f1f1;
# }
# #T_a51d6_row5_col2, #T_a51d6_row5_col3 {
#   background-color: #a70226;
#   color: #f1f1f1;
# }
# #T_a51d6_row5_col4 {
#   background-color: #fee08b;
#   color: #000000;
# }
# #T_a51d6_row6_col0 {
#   background-color: #fffbb8;
#   color: #000000;
# }
# #T_a51d6_row6_col1 {
#   background-color: #8ccd67;
#   color: #000000;
# }
# #T_a51d6_row6_col2, #T_a51d6_row8_col3 {
#   background-color: #ce2827;
#   color: #f1f1f1;
# }
# #T_a51d6_row7_col0 {
#   background-color: #e8f59f;
#   color: #000000;
# }
# #T_a51d6_row7_col1 {
#   background-color: #70c164;
#   color: #000000;
# }
# #T_a51d6_row7_col2 {
#   background-color: #d62f27;
#   color: #f1f1f1;
# }
# #T_a51d6_row7_col3 {
#   background-color: #ef633f;
#   color: #f1f1f1;
# }
# #T_a51d6_row8_col0 {
#   background-color: #da362a;
#   color: #f1f1f1;
# }
# #T_a51d6_row8_col1 {
#   background-color: #e24731;
#   color: #f1f1f1;
# }
# #T_a51d6_row8_col4 {
#   background-color: #fee593;
#   color: #000000;
# }
# #T_a51d6_row9_col2 {
#   background-color: #feeb9d;
#   color: #000000;
# }
# #T_a51d6_row9_col3 {
#   background-color: #84ca66;
#   color: #000000;
# }
# </style>
# <table id="T_a51d6">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Attrition</th>
#       <th id="T_a51d6_level0_col0" class="col_heading level0 col0" colspan="2">No</th>
#       <th id="T_a51d6_level0_col2" class="col_heading level0 col2" colspan="2">Yes</th>
#       <th id="T_a51d6_level0_col4" class="col_heading level0 col4" >Total</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Gender</th>
#       <th id="T_a51d6_level1_col0" class="col_heading level1 col0" >Female</th>
#       <th id="T_a51d6_level1_col1" class="col_heading level1 col1" >Male</th>
#       <th id="T_a51d6_level1_col2" class="col_heading level1 col2" >Female</th>
#       <th id="T_a51d6_level1_col3" class="col_heading level1 col3" >Male</th>
#       <th id="T_a51d6_level1_col4" class="col_heading level1 col4" ></th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >JobRole</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a51d6_level0_row0" class="row_heading level0 row0" >Healthcare Representative</th>
#       <td id="T_a51d6_row0_col0" class="data row0 col0" >46</td>
#       <td id="T_a51d6_row0_col1" class="data row0 col1" >76</td>
#       <td id="T_a51d6_row0_col2" class="data row0 col2" >5</td>
#       <td id="T_a51d6_row0_col3" class="data row0 col3" >4</td>
#       <td id="T_a51d6_row0_col4" class="data row0 col4" >131</td>
#     </tr>
#     <tr>
#       <th id="T_a51d6_level0_row1" class="row_heading level0 row1" >Human Resources</th>
#       <td id="T_a51d6_row1_col0" class="data row1 col0" >10</td>
#       <td id="T_a51d6_row1_col1" class="data row1 col1" >30</td>
#       <td id="T_a51d6_row1_col2" class="data row1 col2" >6</td>
#       <td id="T_a51d6_row1_col3" class="data row1 col3" >6</td>
#       <td id="T_a51d6_row1_col4" class="data row1 col4" >52</td>
#     </tr>
#     <tr>
#       <th id="T_a51d6_level0_row2" class="row_heading level0 row2" >Laboratory Technician</th>
#       <td id="T_a51d6_row2_col0" class="data row2 col0" >69</td>
#       <td id="T_a51d6_row2_col1" class="data row2 col1" >128</td>
#       <td id="T_a51d6_row2_col2" class="data row2 col2" >16</td>
#       <td id="T_a51d6_row2_col3" class="data row2 col3" >46</td>
#       <td id="T_a51d6_row2_col4" class="data row2 col4" >259</td>
#     </tr>
#     <tr>
#       <th id="T_a51d6_level0_row3" class="row_heading level0 row3" >Manager</th>
#       <td id="T_a51d6_row3_col0" class="data row3 col0" >45</td>
#       <td id="T_a51d6_row3_col1" class="data row3 col1" >52</td>
#       <td id="T_a51d6_row3_col2" class="data row3 col2" >2</td>
#       <td id="T_a51d6_row3_col3" class="data row3 col3" >3</td>
#       <td id="T_a51d6_row3_col4" class="data row3 col4" >102</td>
#     </tr>
#     <tr>
#       <th id="T_a51d6_level0_row4" class="row_heading level0 row4" >Manufacturing Director</th>
#       <td id="T_a51d6_row4_col0" class="data row4 col0" >68</td>
#       <td id="T_a51d6_row4_col1" class="data row4 col1" >67</td>
#       <td id="T_a51d6_row4_col2" class="data row4 col2" >4</td>
#       <td id="T_a51d6_row4_col3" class="data row4 col3" >6</td>
#       <td id="T_a51d6_row4_col4" class="data row4 col4" >145</td>
#     </tr>
#     <tr>
#       <th id="T_a51d6_level0_row5" class="row_heading level0 row5" >Research Director</th>
#       <td id="T_a51d6_row5_col0" class="data row5 col0" >32</td>
#       <td id="T_a51d6_row5_col1" class="data row5 col1" >46</td>
#       <td id="T_a51d6_row5_col2" class="data row5 col2" >1</td>
#       <td id="T_a51d6_row5_col3" class="data row5 col3" >1</td>
#       <td id="T_a51d6_row5_col4" class="data row5 col4" >80</td>
#     </tr>
#     <tr>
#       <th id="T_a51d6_level0_row6" class="row_heading level0 row6" >Research Scientist</th>
#       <td id="T_a51d6_row6_col0" class="data row6 col0" >97</td>
#       <td id="T_a51d6_row6_col1" class="data row6 col1" >148</td>
#       <td id="T_a51d6_row6_col2" class="data row6 col2" >17</td>
#       <td id="T_a51d6_row6_col3" class="data row6 col3" >30</td>
#       <td id="T_a51d6_row6_col4" class="data row6 col4" >292</td>
#     </tr>
#     <tr>
#       <th id="T_a51d6_level0_row7" class="row_heading level0 row7" >Sales Executive</th>
#       <td id="T_a51d6_row7_col0" class="data row7 col0" >112</td>
#       <td id="T_a51d6_row7_col1" class="data row7 col1" >157</td>
#       <td id="T_a51d6_row7_col2" class="data row7 col2" >20</td>
#       <td id="T_a51d6_row7_col3" class="data row7 col3" >37</td>
#       <td id="T_a51d6_row7_col4" class="data row7 col4" >326</td>
#     </tr>
#     <tr>
#       <th id="T_a51d6_level0_row8" class="row_heading level0 row8" >Sales Representative</th>
#       <td id="T_a51d6_row8_col0" class="data row8 col0" >22</td>
#       <td id="T_a51d6_row8_col1" class="data row8 col1" >28</td>
#       <td id="T_a51d6_row8_col2" class="data row8 col2" >16</td>
#       <td id="T_a51d6_row8_col3" class="data row8 col3" >17</td>
#       <td id="T_a51d6_row8_col4" class="data row8 col4" >83</td>
#     </tr>
#     <tr>
#       <th id="T_a51d6_level0_row9" class="row_heading level0 row9" >Total</th>
#       <td id="T_a51d6_row9_col0" class="data row9 col0" >501</td>
#       <td id="T_a51d6_row9_
# <style type="text/css">
# #T_0b524_row0_col0 {
#   background-color: #fdc776;
#   color: #000000;
# }
# #T_0b524_row0_col1 {
#   background-color: #e0f295;
#   color: #000000;
# }
# #T_0b524_row0_col2 {
#   background-color: #b71126;
#   color: #f1f1f1;
# }
# #T_0b524_row0_col3, #T_0b524_row3_col3, #T_0b524_row4_col2 {
#   background-color: #b30d26;
#   color: #f1f1f1;
# }
# #T_0b524_row1_col0, #T_0b524_row8_col2 {
#   background-color: #f26841;
#   color: #f1f1f1;
# }
# #T_0b524_row1_col1, #T_0b524_row5_col1 {
#   background-color: #e2f397;
#   color: #000000;
# }
# #T_0b524_row1_col2, #T_0b524_row1_col3, #T_0b524_row7_col3 {
#   background-color: #db382b;
#   color: #f1f1f1;
# }
# #T_0b524_row2_col0 {
#   background-color: #fa9857;
#   color: #000000;
# }
# #T_0b524_row2_col1 {
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_0b524_row2_col2, #T_0b524_row7_col2, #T_0b524_row9_col2 {
#   background-color: #c21c27;
#   color: #f1f1f1;
# }
# #T_0b524_row2_col3 {
#   background-color: #ed5f3c;
#   color: #f1f1f1;
# }
# #T_0b524_row3_col0 {
#   background-color: #feec9f;
#   color: #000000;
# }
# #T_0b524_row3_col1 {
#   background-color: #fbfdba;
#   color: #000000;
# }
# #T_0b524_row3_col2 {
#   background-color: #af0926;
#   color: #f1f1f1;
# }
# #T_0b524_row4_col0 {
#   background-color: #fff6b0;
#   color: #000000;
# }
# #T_0b524_row4_col1 {
#   background-color: #fff3ac;
#   color: #000000;
# }
# #T_0b524_row4_col3 {
#   background-color: #b91326;
#   color: #f1f1f1;
# }
# #T_0b524_row5_col0 {
#   background-color: #fee08b;
#   color: #000000;
# }
# #T_0b524_row5_col2, #T_0b524_row5_col3 {
#   background-color: #ab0626;
#   color: #f1f1f1;
# }
# #T_0b524_row6_col0 {
#   background-color: #fdbf6f;
#   color: #000000;
# }
# #T_0b524_row6_col1 {
#   background-color: #fdfebc;
#   color: #000000;
# }
# #T_0b524_row6_col2 {
#   background-color: #c01a27;
#   color: #f1f1f1;
# }
# #T_0b524_row6_col3, #T_0b524_row9_col3 {
#   background-color: #d83128;
#   color: #f1f1f1;
# }
# #T_0b524_row7_col0, #T_0b524_row9_col0 {
#   background-color: #fdc372;
#   color: #000000;
# }
# #T_0b524_row7_col1 {
#   background-color: #fffab6;
#   color: #000000;
# }
# #T_0b524_row8_col0 {
#   background-color: #fa9656;
#   color: #000000;
# }
# #T_0b524_row8_col1 {
#   background-color: #fdc171;
#   color: #000000;
# }
# #T_0b524_row8_col3 {
#   background-color: #f47044;
#   color: #f1f1f1;
# }
# #T_0b524_row9_col1 {
#   background-color: #fffebe;
#   color: #000000;
# }
# </style>
# <table id="T_0b524">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Attrition</th>
#       <th id="T_0b524_level0_col0" class="col_heading level0 col0" colspan="2">No</th>
#       <th id="T_0b524_level0_col2" class="col_heading level0 col2" colspan="2">Yes</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Gender</th>
#       <th id="T_0b524_level1_col0" class="col_heading level1 col0" >Female</th>
#       <th id="T_0b524_level1_col1" class="col_heading level1 col1" >Male</th>
#       <th id="T_0b524_level1_col2" class="col_heading level1 col2" >Female</th>
#       <th id="T_0b524_level1_col3" class="col_heading level1 col3" >Male</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >JobRole</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0b524_level0_row0" class="row_heading level0 row0" >Healthcare Representative</th>
#       <td id="T_0b524_row0_col0" class="data row0 col0" >35.11%</td>
#       <td id="T_0b524_row0_col1" class="data row0 col1" >58.02%</td>
#       <td id="T_0b524_row0_col2" class="data row0 col2" >3.82%</td>
#       <td id="T_0b524_row0_col3" class="data row0 col3" >3.05%</td>
#     </tr>
#     <tr>
#       <th id="T_0b524_level0_row1" class="row_heading level0 row1" >Human Resources</th>
#       <td id="T_0b524_row1_col0" class="data row1 col0" >19.23%</td>
#       <td id="T_0b524_row1_col1" class="data row1 col1" >57.69%</td>
#       <td id="T_0b524_row1_col2" class="data row1 col2" >11.54%</td>
#       <td id="T_0b524_row1_col3" class="data row1 col3" >11.54%</td>
#     </tr>
#     <tr>
#       <th id="T_0b524_level0_row2" class="row_heading level0 row2" >Laboratory Technician</th>
#       <td id="T_0b524_row2_col0" class="data row2 col0" >26.64%</td>
#       <td id="T_0b524_row2_col1" class="data row2 col1" >49.42%</td>
#       <td id="T_0b524_row2_col2" class="data row2 col2" >6.18%</td>
#       <td id="T_0b524_row2_col3" class="data row2 col3" >17.76%</td>
#     </tr>
#     <tr>
#       <th id="T_0b524_level0_row3" class="row_heading level0 row3" >Manager</th>
#       <td id="T_0b524_row3_col0" class="data row3 col0" >44.12%</td>
#       <td id="T_0b524_row3_col1" class="data row3 col1" >50.98%</td>
#       <td id="T_0b524_row3_col2" class="data row3 col2" >1.96%</td>
#       <td id="T_0b524_row3_col3" class="data row3 col3" >2.94%</td>
#     </tr>
#     <tr>
#       <th id="T_0b524_level0_row4" class="row_heading level0 row4" >Manufacturing Director</th>
#       <td id="T_0b524_row4_col0" class="data row4 col0" >46.90%</td>
#       <td id="T_0b524_row4_col1" class="data row4 col1" >46.21%</td>
#       <td id="T_0b524_row4_col2" class="data row4 col2" >2.76%</td>
#       <td id="T_0b524_row4_col3" class="data row4 col3" >4.14%</td>
#     </tr>
#     <tr>
#       <th id="T_0b524_level0_row5" class="row_heading level0 row5" >Research Director</th>
#       <td id="T_0b524_row5_col0" class="data row5 col0" >40.00%</td>
#       <td id="T_0b524_row5_col1" class="data row5 col1" >57.50%</td>
#       <td id="T_0b524_row5_col2" class="data row5 col2" >1.25%</td>
#       <td id="T_0b524_row5_col3" class="data row5 col3" >1.25%</td>
#     </tr>
#     <tr>
#       <th id="T_0b524_level0_row6" class="row_heading level0 row6" >Research Scientist</th>
#       <td id="T_0b524_row6_col0" class="data row6 col0" >33.22%</td>
#       <td id="T_0b524_row6_col1" class="data row6 col1" >50.68%</td>
#       <td id="T_0b524_row6_col2" class="data row6 col2" >5.82%</td>
#       <td id="T_0b524_row6_col3" class="data row6 col3" >10.27%</td>
#     </tr>
#     <tr>
#       <th id="T_0b524_level0_row7" class="row_heading level0 row7" >Sales Executive</th>
#       <td id="T_0b524_row7_col0" class="data row7 col0" >34.36%</td>
#       <td id="T_0b524_row7_col1" class="data row7 col1" >48.16%</td>
#       <td id="T_0b524_row7_col2" class="data row7 col2" >6.13%</td>
#       <td id="T_0b524_row7_col3" class="data row7 col3" >11.35%</td>
#     </tr>
#     <tr>
#       <th id="T_0b524_level0_row8" class="row_heading level0 row8" >Sales Representative</th>
#       <td id="T_0b524_row8_col0" class="data row8 col0" >26.51%</td>
#       <td id="T_0b524_row8_col1" class="data row8 col1" >33.73%</td>
#       <td id="T_0b524_row8_col2" class="data row8 col2" >19.28%</td>
#       <td id="T_0b524_row8_col3" class="data row8 col3" >20.48%</td>
#     </tr>
#     <tr>
#       <th id="T_0b524_level0_row9" class="row_heading level0 row9" >Total</th>
#       <td id="T_0b524_row9_col0" class="data row9 col0" >34.08%</td>
#       <td id="T_0b524_row9_col1" class="data row9 col1" >49.80%</td>
#       <td id="T_0b524_row9_col2" class="data row9 col2" >5.92%</td>
#       <td id="T_0b524_row9_col3" class="data row9 col3" >10.20%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# * Agrupamentos: média de salário por cargo

# %%
with pd.option_context("float_format", "$ {:_.2f}".format):
    display(
        df_colunas_removidas.pivot_table(
            index=["JobRole", "JobLevel"], 
            columns="Attrition", 
            aggfunc=["mean", "size"],
            values="MonthlyIncome", 
            observed=False
        ).dropna(
            how="all", 
            subset=[("mean", "No"), ("mean", "Yes")]
        )
    )
# Out:
#                                           mean             size
# Attrition                                   No         Yes   No Yes
# JobRole                   JobLevel
# Healthcare Representative 2         $ 5_828.28  $ 6_792.00   75   3
#                           3         $ 9_426.28  $ 8_877.80   39   5
#                           4        $ 13_073.50 $ 12_169.00    8   1
# Human Resources           1         $ 2_871.26  $ 2_415.70   23  10
#                           2         $ 5_563.46         NaN   13   0
#                           3         $ 9_326.50 $ 10_216.00    4   2
# Laboratory Technician     1         $ 2_921.71  $ 2_682.00  144  56
#                           2         $ 4_394.00  $ 5_084.20   51   5
#                           3         $ 6_306.50  $ 5_381.00    2   1
# Manager                   3        $ 12_133.70 $ 12_729.50   10   2
#                           4        $ 16_613.28         NaN   47   0
#                           5        $ 19_159.58 $ 19_509.33   40   3
# Manufacturing Director    2         $ 5_644.87  $ 5_066.80   85   5
#                           3         $ 9_262.40  $ 9_664.20   40   5
#                           4        $ 13_383.00         NaN   10   0
# Research Director         3        $ 12_721.57         NaN   28   0
#                           4        $ 16_429.04         NaN   26   0
#                           5        $ 19_188.92 $ 19_395.50   24   2
# Research Scientist        1         $ 2_859.46  $ 2_694.07  189  45
#                           2         $ 4_822.35  $ 4_724.50   55   2
#                           3         $ 9_724.00         NaN    1   0
# Sales Executive           2         $ 5_760.22  $ 6_023.42  197  36
#                           3         $ 9_103.66  $ 9_202.76   62  17
#                           4        $ 13_125.20 $ 13_395.75   10   4
# Sales Representative      1         $ 2_603.66  $ 2_373.44   44  32
#                           2         $ 4_226.83  $ 2_086.00    6   1

# %% [markdown]
# * Agrupamentos: média de salário por cargo e nível

# %%
with pd.option_context("float_format", "$ {:_.2f}".format):
    display(
        df_colunas_removidas.pivot_table(
            index=["JobRole", "JobLevel"], 
            columns=["Attrition"], 
            aggfunc=["mean", "size"],
            values="MonthlyIncome",
            observed=False
        ).dropna(
            how="all",
            subset=[("mean", "No"), ("mean", "Yes")]
        )
    )
# Out:
#                                           mean             size
# Attrition                                   No         Yes   No Yes
# JobRole                   JobLevel
# Healthcare Representative 2         $ 5_828.28  $ 6_792.00   75   3
#                           3         $ 9_426.28  $ 8_877.80   39   5
#                           4        $ 13_073.50 $ 12_169.00    8   1
# Human Resources           1         $ 2_871.26  $ 2_415.70   23  10
#                           2         $ 5_563.46         NaN   13   0
#                           3         $ 9_326.50 $ 10_216.00    4   2
# Laboratory Technician     1         $ 2_921.71  $ 2_682.00  144  56
#                           2         $ 4_394.00  $ 5_084.20   51   5
#                           3         $ 6_306.50  $ 5_381.00    2   1
# Manager                   3        $ 12_133.70 $ 12_729.50   10   2
#                           4        $ 16_613.28         NaN   47   0
#                           5        $ 19_159.58 $ 19_509.33   40   3
# Manufacturing Director    2         $ 5_644.87  $ 5_066.80   85   5
#                           3         $ 9_262.40  $ 9_664.20   40   5
#                           4        $ 13_383.00         NaN   10   0
# Research Director         3        $ 12_721.57         NaN   28   0
#                           4        $ 16_429.04         NaN   26   0
#                           5        $ 19_188.92 $ 19_395.50   24   2
# Research Scientist        1         $ 2_859.46  $ 2_694.07  189  45
#                           2         $ 4_822.35  $ 4_724.50   55   2
#                           3         $ 9_724.00         NaN    1   0
# Sales Executive           2         $ 5_760.22  $ 6_023.42  197  36
#                           3         $ 9_103.66  $ 9_202.76   62  17
#                           4        $ 13_125.20 $ 13_395.75   10   4
# Sales Representative      1         $ 2_603.66  $ 2_373.44   44  32
#                           2         $ 4_226.83  $ 2_086.00    6   1

# %% [markdown]
# * Agrupamentos: gênero por departamento

# %%
with pd.option_context("float_format", "{:_.2%}".format):
    display(
        df_colunas_removidas.pivot_table(
            index="Department", 
            columns=["Attrition", "Gender"], 
            aggfunc="size",
            observed=False,
        )
    )

    display(
        pd.crosstab(
            index=df_colunas_removidas["Department"], 
            columns=[df_colunas_removidas["Attrition"], df_colunas_removidas["Gender"]], 
            normalize="index",
            margins=True,
            margins_name="Total"
        )
    )
# Out:
# Attrition                  No         Yes
# Gender                 Female Male Female Male
# Department
# Human Resources            14   37      6    6
# Research & Development    336  492     43   90
# Sales                     151  203     38   54
# Attrition                  No           Yes
# Gender                 Female   Male Female   Male
# Department
# Human Resources        22.22% 58.73%  9.52%  9.52%
# Research & Development 34.96% 51.20%  4.47%  9.37%
# Sales                  33.86% 45.52%  8.52% 12.11%
# Total                  34.08% 49.80%  5.92% 10.20%

# %% [markdown]
# * Agrupamentos: média de salário por nível educacional

# %% [markdown]
# ### Análise por média

# %%
mapeamento_educacao = {
    1: "Below College",
    2: "Collage",
    3: "Bachelor",
    4: "Master",
    5: "PhD",
}

with pd.option_context("float_format", "$ {:_.2f}".format):
    display(
        pd.crosstab(
            index=[df_colunas_removidas["Department"], df_colunas_removidas["Education"]], 
            columns=df_colunas_removidas["Attrition"], 
            aggfunc="mean",
            values=df_colunas_removidas["MonthlyIncome"],
        ).rename(
            index=mapeamento_educacao,
        )
    )
# Out:
# Attrition                                     No        Yes
# Department             Education
# Human Resources        Below College  $ 3_082.00 $ 1_555.00
#                        Collage        $ 4_698.40 $ 5_064.67
#                        Bachelor       $ 7_182.91 $ 4_332.00
#                        Master        $ 11_509.25 $ 2_518.67
#                        PhD            $ 6_007.50 $ 2_956.00
# Research & Development Below College  $ 6_134.57 $ 3_933.16
#                        Collage        $ 6_569.61 $ 3_566.48
#                        Bachelor       $ 6_625.23 $ 3_887.45
#                        Master         $ 6_667.56 $ 4_742.41
#                        PhD            $ 8_503.96 $ 6_720.33
# Sales                  Below College  $ 5_704.74 $ 5_352.73
#                        Collage        $ 6_897.54 $ 5_067.17
#                        Bachelor       $ 7_483.97 $ 6_082.79
#                        Master         $ 7_475.05 $ 6_527.22
#                        PhD            $ 9_032.43 $ 6_134.00

# %% [markdown]
# ### Análise por quantidade

# %%
df_analisada = pd.crosstab(
        index=[df_colunas_removidas["Department"], df_colunas_removidas["Education"]], 
        columns=df_colunas_removidas["Attrition"], 
        margins=True,
        margins_name="Total",
    ).rename(
        index=mapeamento_educacao
    )

display(
    df_analisada.style.background_gradient(
        cmap="RdYlGn_r",
        axis="columns",
        subset=["Yes"],
        vmax=df_analisada["Yes"].iloc[:-1].max(),
        vmin=0,
    )
)
# Out:
# <style type="text/css">
# #T_3ad5e_row0_col1, #T_3ad5e_row4_col1, #T_3ad5e_row14_col1 {
#   background-color: #04703b;
#   color: #f1f1f1;
# }
# #T_3ad5e_row1_col1, #T_3ad5e_row3_col1, #T_3ad5e_row9_col1 {
#   background-color: #0d8044;
#   color: #f1f1f1;
# }
# #T_3ad5e_row2_col1 {
#   background-color: #128a49;
#   color: #f1f1f1;
# }
# #T_3ad5e_row5_col1 {
#   background-color: #b9e176;
#   color: #000000;
# }
# #T_3ad5e_row6_col1, #T_3ad5e_row13_col1 {
#   background-color: #ddf191;
#   color: #000000;
# }
# #T_3ad5e_row7_col1, #T_3ad5e_row15_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_3ad5e_row8_col1 {
#   background-color: #fee999;
#   color: #000000;
# }
# #T_3ad5e_row10_col1 {
#   background-color: #63bc62;
#   color: #f1f1f1;
# }
# #T_3ad5e_row11_col1 {
#   background-color: #b1de71;
#   color: #000000;
# }
# #T_3ad5e_row12_col1 {
#   background-color: #fdaf62;
#   color: #000000;
# }
# </style>
# <table id="T_3ad5e">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Attrition</th>
#       <th id="T_3ad5e_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_3ad5e_level0_col1" class="col_heading level0 col1" >Yes</th>
#       <th id="T_3ad5e_level0_col2" class="col_heading level0 col2" >Total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Department</th>
#       <th class="index_name level1" >Education</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3ad5e_level0_row0" class="row_heading level0 row0" rowspan="5">Human Resources</th>
#       <th id="T_3ad5e_level1_row0" class="row_heading level1 row0" >Below College</th>
#       <td id="T_3ad5e_row0_col0" class="data row0 col0" >4</td>
#       <td id="T_3ad5e_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_3ad5e_row0_col2" class="data row0 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_3ad5e_level1_row1" class="row_heading level1 row1" >Collage</th>
#       <td id="T_3ad5e_row1_col0" class="data row1 col0" >10</td>
#       <td id="T_3ad5e_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_3ad5e_row1_col2" class="data row1 col2" >13</td>
#     </tr>
#     <tr>
#       <th id="T_3ad5e_level1_row2" class="row_heading level1 row2" >Bachelor</th>
#       <td id="T_3ad5e_row2_col0" class="data row2 col0" >23</td>
#       <td id="T_3ad5e_row2_col1" class="data row2 col1" >4</td>
#       <td id="T_3ad5e_row2_col2" class="data row2 col2" >27</td>
#     </tr>
#     <tr>
#       <th id="T_3ad5e_level1_row3" class="row_heading level1 row3" >Master</th>
#       <td id="T_3ad5e_row3_col0" class="data row3 col0" >12</td>
#       <td id="T_3ad5e_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_3ad5e_row3_col2" class="data row3 col2" >15</td>
#     </tr>
#     <tr>
#       <th id="T_3ad5e_level1_row4" class="row_heading level1 row4" >PhD</th>
#       <td id="T_3ad5e_row4_col0" class="data row4 col0" >2</td>
#       <td id="T_3ad5e_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_3ad5e_row4_col2" class="data row4 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_3ad5e_level0_row5" class="row_heading level0 row5" rowspan="5">Research & Development</th>
#       <th id="T_3ad5e_level1_row5" class="row_heading level1 row5" >Below College</th>
#       <td id="T_3ad5e_row5_col0" class="data row5 col0" >96</td>
#       <td id="T_3ad5e_row5_col1" class="data row5 col1" >19</td>
#       <td id="T_3ad5e_row5_col2" class="data row5 col2" >115</td>
#     </tr>
#     <tr>
#       <th id="T_3ad5e_level1_row6" class="row_heading level1 row6" >Collage</th>
#       <td id="T_3ad5e_row6_col0" class="data row6 col0" >159</td>
#       <td id="T_3ad5e_row6_col1" class="data row6 col1" >23</td>
#       <td id="T_3ad5e_row6_col2" class="data row6 col2" >182</td>
#     </tr>
#     <tr>
#       <th id="T_3ad5e_level1_row7" class="row_heading level1 row7" >Bachelor</th>
#       <td id="T_3ad5e_row7_col0" class="data row7 col0" >323</td>
#       <td id="T_3ad5e_row7_col1" class="data row7 col1" >56</td>
#       <td id="T_3ad5e_row7_col2" class="data row7 col2" >379</td>
#     </tr>
#     <tr>
#       <th id="T_3ad5e_level1_row8" class="row_heading level1 row8" >Master</th>
#       <td id="T_3ad5e_row8_col0" class="data row8 col0" >223</td>
#       <td id="T_3ad5e_row8_col1" class="data row8 col1" >32</td>
#       <td id="T_3ad5e_row8_col2" class="data row8 col2" >255</td>
#     </tr>
#     <tr>
#       <th id="T_3ad5e_level1_row9" class="row_heading level1 row9" >PhD</th>
#       <td id="T_3ad5e_row9_col0" class="data row9 col0" >27</td>
#       <td id="T_3ad5e_row9_col1" class="data row9 col1" >3</td>
#       <td id="T_3ad5e_row9_col2" class="data row9 col2" >30</td>
#     </tr>
#     <tr>
#       <th id="T_3ad5e_level0_row10" class="row_heading level0 row10" rowspan="5">Sales</th>
#       <th id="T_3ad5e_level1_row10" class="row_heading level1 row10" >Below College</th>
#       <td id="T_3ad5e_row10_col0" class="data row10 col0" >39</td>
#       <td id="T_3ad5e_row10_col1" class="data row10 col1" >11</td>
#       <td id="T_3ad5e_row10_col2" class="data row10 col2" >50</td>
#     </tr>
#     <tr>
#       <th id="T_3ad5e_level1_row11" class="row_heading level1 row11" >Collage</th>
#       <td id="T_3ad5e_row11_col0" class="data row11 col0" >69</td>
#       <td id="T_3ad5e_row11_col1" class="data row11 col1" >18</td>
#       <td id="T_3ad5e_row11_col2" class="data row11 col2" >87</td>
#     </tr>
#     <tr>
#       <th id="T_3ad5e_level1_row12" class="row_heading level1 row12" >Bachelor</th>
#       <td id="T_3ad5e_row12_col0" class="data row12 col0" >127</td>
#       <td id="T_3ad5e_row12_col1" class="data row12 col1" >39</td>
#       <td id="T_3ad5e_row12_col2" class="data row12 col2" >166</td>
#     </tr>
#     <tr>
#       <th id="T_3ad5e_level1_row13" class="row_heading level1 row13" >Master</th>
#       <td id="T_3ad5e_row13_col0" class="data row13 col0" >105</td>
#       <td id="T_3ad5e_row13_col1" class="data row13 col1" >23</td>
#       <td id="T_3ad5e_row13_col2" class="data row13 col2" >128</td>
#     </tr>
#     <tr>
#       <th id="T_3ad5e_level1_row14" class="row_heading level1 row14" >PhD</th>
#       <td id="T_3ad5e_row14_col0" class="data row14 col0" >14</td>
#       <td id="T_3ad5e_row14_col1" class="data row14 col1" >1</td>
#       <td id="T_3ad5e_row14_col2" class="data row14 col2" >15</td>
#     </tr>
#     <tr>
#       <th id="T_3ad5e_level0_row15" class="row_heading level0 row15" >Total</th>
#       <th id="T_3ad5e_level1_row15" class="row_heading level1 row15" ></th>
#       <td id="T_3ad5e_row15_col0" class="data row15 col0" >1233</td>
#       <td id="T_3ad5e_row15_col1" class="data row15 col1" >237</td>
#       <td id="T_3ad5e_row15_col2" class="data row15 col2" >1470</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Análise por porcetagem

# %%
display(
    pd.crosstab(
        index=[df_colunas_removidas["Department"], df_colunas_removidas["Education"]], 
        columns=df_colunas_removidas["Attrition"], 
        aggfunc="size",
        values=df_colunas_removidas["MonthlyIncome"],
        normalize="index",
    ).rename(
        index=mapeamento_educacao
    ).style.background_gradient(
        cmap="RdYlGn",
        axis="columns",
        vmax=1,
        vmin=0,
    ).format(
        "{:.2%}"
    )
)
# Out:
# <style type="text/css">
# #T_54e7b_row0_col0, #T_54e7b_row3_col0 {
#   background-color: #66bd63;
#   color: #f1f1f1;
# }
# #T_54e7b_row0_col1, #T_54e7b_row3_col1 {
#   background-color: #f46d43;
#   color: #f1f1f1;
# }
# #T_54e7b_row1_col0 {
#   background-color: #7ac665;
#   color: #000000;
# }
# #T_54e7b_row1_col1 {
#   background-color: #f7814c;
#   color: #f1f1f1;
# }
# #T_54e7b_row2_col0, #T_54e7b_row7_col0 {
#   background-color: #3ca959;
#   color: #f1f1f1;
# }
# #T_54e7b_row2_col1, #T_54e7b_row7_col1 {
#   background-color: #e44c34;
#   color: #f1f1f1;
# }
# #T_54e7b_row4_col0 {
#   background-color: #b7e075;
#   color: #000000;
# }
# #T_54e7b_row4_col1 {
#   background-color: #fdbf6f;
#   color: #000000;
# }
# #T_54e7b_row5_col0 {
#   background-color: #4bb05c;
#   color: #f1f1f1;
# }
# #T_54e7b_row5_col1 {
#   background-color: #ea5739;
#   color: #f1f1f1;
# }
# #T_54e7b_row6_col0, #T_54e7b_row8_col0 {
#   background-color: #2da155;
#   color: #f1f1f1;
# }
# #T_54e7b_row6_col1, #T_54e7b_row8_col1 {
#   background-color: #de402e;
#   color: #f1f1f1;
# }
# #T_54e7b_row9_col0 {
#   background-color: #199750;
#   color: #f1f1f1;
# }
# #T_54e7b_row9_col1 {
#   background-color: #d62f27;
#   color: #f1f1f1;
# }
# #T_54e7b_row10_col0 {
#   background-color: #73c264;
#   color: #000000;
# }
# #T_54e7b_row10_col1 {
#   background-color: #f67a49;
#   color: #f1f1f1;
# }
# #T_54e7b_row11_col0 {
#   background-color: #69be63;
#   color: #f1f1f1;
# }
# #T_54e7b_row11_col1 {
#   background-color: #f47044;
#   color: #f1f1f1;
# }
# #T_54e7b_row12_col0 {
#   background-color: #7dc765;
#   color: #000000;
# }
# #T_54e7b_row12_col1 {
#   background-color: #f7844e;
#   color: #f1f1f1;
# }
# #T_54e7b_row13_col0 {
#   background-color: #54b45f;
#   color: #f1f1f1;
# }
# #T_54e7b_row13_col1 {
#   background-color: #ee613e;
#   color: #f1f1f1;
# }
# #T_54e7b_row14_col0 {
#   background-color: #118848;
#   color: #f1f1f1;
# }
# #T_54e7b_row14_col1 {
#   background-color: #c62027;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_54e7b">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Attrition</th>
#       <th id="T_54e7b_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_54e7b_level0_col1" class="col_heading level0 col1" >Yes</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Department</th>
#       <th class="index_name level1" >Education</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_54e7b_level0_row0" class="row_heading level0 row0" rowspan="5">Human Resources</th>
#       <th id="T_54e7b_level1_row0" class="row_heading level1 row0" >Below College</th>
#       <td id="T_54e7b_row0_col0" class="data row0 col0" >80.00%</td>
#       <td id="T_54e7b_row0_col1" class="data row0 col1" >20.00%</td>
#     </tr>
#     <tr>
#       <th id="T_54e7b_level1_row1" class="row_heading level1 row1" >Collage</th>
#       <td id="T_54e7b_row1_col0" class="data row1 col0" >76.92%</td>
#       <td id="T_54e7b_row1_col1" class="data row1 col1" >23.08%</td>
#     </tr>
#     <tr>
#       <th id="T_54e7b_level1_row2" class="row_heading level1 row2" >Bachelor</th>
#       <td id="T_54e7b_row2_col0" class="data row2 col0" >85.19%</td>
#       <td id="T_54e7b_row2_col1" class="data row2 col1" >14.81%</td>
#     </tr>
#     <tr>
#       <th id="T_54e7b_level1_row3" class="row_heading level1 row3" >Master</th>
#       <td id="T_54e7b_row3_col0" class="data row3 col0" >80.00%</td>
#       <td id="T_54e7b_row3_col1" class="data row3 col1" >20.00%</td>
#     </tr>
#     <tr>
#       <th id="T_54e7b_level1_row4" class="row_heading level1 row4" >PhD</th>
#       <td id="T_54e7b_row4_col0" class="data row4 col0" >66.67%</td>
#       <td id="T_54e7b_row4_col1" class="data row4 col1" >33.33%</td>
#     </tr>
#     <tr>
#       <th id="T_54e7b_level0_row5" class="row_heading level0 row5" rowspan="5">Research & Development</th>
#       <th id="T_54e7b_level1_row5" class="row_heading level1 row5" >Below College</th>
#       <td id="T_54e7b_row5_col0" class="data row5 col0" >83.48%</td>
#       <td id="T_54e7b_row5_col1" class="data row5 col1" >16.52%</td>
#     </tr>
#     <tr>
#       <th id="T_54e7b_level1_row6" class="row_heading level1 row6" >Collage</th>
#       <td id="T_54e7b_row6_col0" class="data row6 col0" >87.36%</td>
#       <td id="T_54e7b_row6_col1" class="data row6 col1" >12.64%</td>
#     </tr>
#     <tr>
#       <th id="T_54e7b_level1_row7" class="row_heading level1 row7" >Bachelor</th>
#       <td id="T_54e7b_row7_col0" class="data row7 col0" >85.22%</td>
#       <td id="T_54e7b_row7_col1" class="data row7 col1" >14.78%</td>
#     </tr>
#     <tr>
#       <th id="T_54e7b_level1_row8" class="row_heading level1 row8" >Master</th>
#       <td id="T_54e7b_row8_col0" class="data row8 col0" >87.45%</td>
#       <td id="T_54e7b_row8_col1" class="data row8 col1" >12.55%</td>
#     </tr>
#     <tr>
#       <th id="T_54e7b_level1_row9" class="row_heading level1 row9" >PhD</th>
#       <td id="T_54e7b_row9_col0" class="data row9 col0" >90.00%</td>
#       <td id="T_54e7b_row9_col1" class="data row9 col1" >10.00%</td>
#     </tr>
#     <tr>
#       <th id="T_54e7b_level0_row10" class="row_heading level0 row10" rowspan="5">Sales</th>
#       <th id="T_54e7b_level1_row10" class="row_heading level1 row10" >Below College</th>
#       <td id="T_54e7b_row10_col0" class="data row10 col0" >78.00%</td>
#       <td id="T_54e7b_row10_col1" class="data row10 col1" >22.00%</td>
#     </tr>
#     <tr>
#       <th id="T_54e7b_level1_row11" class="row_heading level1 row11" >Collage</th>
#       <td id="T_54e7b_row11_col0" class="data row11 col0" >79.31%</td>
#       <td id="T_54e7b_row11_col1" class="data row11 col1" >20.69%</td>
#     </tr>
#     <tr>
#       <th id="T_54e7b_level1_row12" class="row_heading level1 row12" >Bachelor</th>
#       <td id="T_54e7b_row12_col0" class="data row12 col0" >76.51%</td>
#       <td id="T_54e7b_row12_col1" class="data row12 col1" >23.49%</td>
#     </tr>
#     <tr>
#       <th id="T_54e7b_level1_row13" class="row_heading level1 row13" >Master</th>
#       <td id="T_54e7b_row13_col0" class="data row13 col0" >82.03%</td>
#       <td id="T_54e7b_row13_col1" class="data row13 col1" >17.97%</td>
#     </tr>
#     <tr>
#       <th id="T_54e7b_level1_row14" class="row_heading level1 row14" >PhD</th>
#       <td id="T_54e7b_row14_col0" class="data row14 col0" >93.33%</td>
#       <td id="T_54e7b_row14_col1" class="data row14 col1" >6.67%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Análise por nível de educação e cargo

# %%
display(
    pd.crosstab(
        index=[df_colunas_removidas["JobRole"], df_colunas_removidas["JobLevel"], df_colunas_removidas["Attrition"], ], 
        columns=[df_colunas_removidas["Education"], ], 
        margins=True,
        margins_name="Total",
    ).rename(
        columns=mapeamento_educacao
    )
)

display(
    pd.crosstab(
        index=[df_colunas_removidas["JobRole"], df_colunas_removidas["JobLevel"], df_colunas_removidas["Attrition"], ], 
        columns=[df_colunas_removidas["Education"], ], 
        aggfunc="size",
        values=df_colunas_removidas["MonthlyIncome"],
        normalize="index",
    ).rename(
        columns=mapeamento_educacao
    ).style.background_gradient(
        cmap="RdYlGn_r",
        axis="columns",
        vmax=1,
        vmin=0,
    ).format(
        "{:.2%}"
    )
)
# Out:
# Education                                     Below College  Collage  \
# JobRole                   JobLevel Attrition
# Healthcare Representative 2        No                     7       13
#                                    Yes                    1        2
#                           3        No                     4        3
#                                    Yes                    1        1
#                           4        No                     2        2
#                                    Yes                    0        0
# Human Resources           1        No                     3        7
#                                    Yes                    1        2
#                           2        No                     1        2
#                           3        No                     0        0
#                                    Yes                    0        1
# Laboratory Technician     1        No                    24       30
#                                    Yes                    8        9
#                           2        No                     3       14
#                                    Yes                    0        2
#                           3        No                     0        1
#                                    Yes                    0        1
# Manager                   3        No                     1        1
#                                    Yes                    1        0
#                           4        No                     4        9
#                           5        No                     2        9
#                                    Yes                    1        0
# Manufacturing Director    2        No                     9       23
#                                    Yes                    1        1
#                           3        No                     4        7
#                                    Yes                    0        0
#                           4        No                     1        2
# Research Director         3        No                     4        5
#                           4        No                     0        4
#                           5        No                     3        4
#                                    Yes                    0        0
# Research Scientist        1        No                    28       26
#                                    Yes                    7        7
#                           2        No                     2       13
#                                    Yes                    0        0
#                           3        No                     0        0
# Sales Executive           2        No                    20       43
#                                    Yes                    1       10
#                           3        No                     3       12
#                                    Yes                    2        1
#                           4        No                     1        0
#                                    Yes                    0        0
# Sales Representative      1        No                    11        6
#                                    Yes                    7        7
#                           2        No                     2        2
#                                    Yes                    0        0
# Total                                                   170      282
#
# Education                                     Bachelor  Master  PhD  Total
# JobRole                   JobLevel Attrition
# Healthcare Representative 2        No               25      28    2     75
#                                    Yes               0       0    0      3
#                           3        No               18      14    0     39
#                                    Yes               2       1    0      5
#                           4        No                2       1    1      8
#                                    Yes               1       0    0      1
# Human Resources           1        No               10       3    0     23
#                                    Yes               3       3    1     10
#                           2        No                6       2    2     13
#                           3        No                2       2    0      4
#                                    Yes               1       0    0      2
# Laboratory Technician     1        No               53      35    2    144
#                                    Yes              29      10    0     56
#                           2        No               19      12    3     51
#                                    Yes               2       1    0      5
#                           3        No                1       0    0      2
#                                    Yes               0       0    0      1
# Manager                   3        No                6       2    0     10
#                                    Yes               0       1    0      2
#                           4        No               17      13    4     47
#                           5        No               15      13    1     40
#                                    Yes               2       0    0      3
# Manufacturing Director    2        No               25      26    2     85
#                                    Yes               1       2    0      5
#                           3        No               23       5    1     40
#                                    Yes               1       2    2      5
#                           4        No                4       3    0     10
# Research Director         3        No                8       9    2     28
#                           4        No               11       7    4     26
#                           5        No               10       6    1     24
#                                    Yes               1       1    0      2
# Research Scientist        1        No               87      44    4    189
#                                    Yes              18      12    1     45
#                           2        No               16      21    3     55
#                                    Yes               0       2    0      2
#                           3        No                1       0    0      1
# Sales Executive           2        No               66      61    7    197
#                                    Yes              10      14    1     36
#                           3        No               26      17    4     62
#                                    Yes               9       5    0     17
#                           4        No                6       3    0     10
#                                    Yes               3       1    0      4
# Sales Representative      1        No               16      11    0     44
#                                    Yes              15       3    0     32
#                           2        No                0       2    0      6
#                                    Yes               1       0    0      1
# Total                                              572     398   48   1470
# <style type="text/css">
# #T_f365b_row0_col0, #T_f365b_row0_col1, #T_f365b_row0_col2, #T_f365b_row0_col3, #T_f365b_row0_col4, #T_f365b_row1_col0, #T_f365b_row1_col1, #T_f365b_row1_col2, #T_f365b_row1_col3, #T_f365b_row1_col4, #T_f365b_row3_col2, #T_f365b_row3_col3, #T_f365b_row3_col4, #T_f365b_row4_col4, #T_f365b_row5_col4, #T_f365b_row7_col0, #T_f365b_row7_col1, #T_f365b_row7_col3, #T_f365b_row7_col4, #T_f365b_row8_col0, #T_f365b_row8_col1, #T_f365b_row8_col2, #T_f365b_row8_col3, #T_f365b_row8_col4, #T_f365b_row9_col0, #T_f365b_row9_col1, #T_f365b_row9_col2, #T_f365b_row9_col3, #T_f365b_row9_col4, #T_f365b_row10_col4, #T_f365b_row13_col0, #T_f365b_row13_col1, #T_f365b_row13_col2, #T_f365b_row13_col3, #T_f365b_row13_col4, #T_f365b_row14_col0, #T_f365b_row14_col1, #T_f365b_row14_col4, #T_f365b_row15_col0, #T_f365b_row15_col3, #T_f365b_row15_col4, #T_f365b_row16_col0, #T_f365b_row16_col1, #T_f365b_row16_col2, #T_f365b_row16_col3, #T_f365b_row16_col4, #T_f365b_row17_col0, #T_f365b_row17_col1, #T_f365b_row17_col2, #T_f365b_row17_col3, #T_f365b_row17_col4, #T_f365b_row18_col0, #T_f365b_row18_col1, #T_f365b_row18_col2, #T_f365b_row18_col3, #T_f365b_row18_col4, #T_f365b_row19_col0, #T_f365b_row19_col1, #T_f365b_row19_col2, #T_f365b_row19_col3, #T_f365b_row19_col4, #T_f365b_row21_col4, #T_f365b_row23_col0, #T_f365b_row23_col4, #T_f365b_row24_col0, #T_f365b_row24_col3, #T_f365b_row24_col4, #T_f365b_row25_col0, #T_f365b_row25_col2, #T_f365b_row25_col3, #T_f365b_row25_col4, #T_f365b_row26_col0, #T_f365b_row26_col1, #T_f365b_row26_col2, #T_f365b_row26_col3, #T_f365b_row26_col4, #T_f365b_row27_col0, #T_f365b_row27_col1, #T_f365b_row27_col2, #T_f365b_row27_col3, #T_f365b_row27_col4, #T_f365b_row28_col0, #T_f365b_row28_col1, #T_f365b_row28_col2, #T_f365b_row28_col3, #T_f365b_row28_col4, #T_f365b_row29_col0, #T_f365b_row29_col1, #T_f365b_row29_col2, #T_f365b_row29_col3, #T_f365b_row29_col4, #T_f365b_row30_col0, #T_f365b_row30_col1, #T_f365b_row30_col2, #T_f365b_row30_col3, #T_f365b_row30_col4, #T_f365b_row31_col0, #T_f365b_row31_col1, #T_f365b_row31_col2, #T_f365b_row31_col3, #T_f365b_row31_col4, #T_f365b_row32_col0, #T_f365b_row32_col1, #T_f365b_row32_col2, #T_f365b_row32_col3, #T_f365b_row32_col4, #T_f365b_row33_col0, #T_f365b_row33_col1, #T_f365b_row33_col2, #T_f365b_row33_col3, #T_f365b_row33_col4, #T_f365b_row34_col4, #T_f365b_row35_col1, #T_f365b_row35_col2, #T_f365b_row35_col4, #T_f365b_row37_col0, #T_f365b_row37_col1, #T_f365b_row37_col2, #T_f365b_row37_col3, #T_f365b_row37_col4, #T_f365b_row39_col1, #T_f365b_row39_col3, #T_f365b_row39_col4, #T_f365b_row40_col0, #T_f365b_row40_col1, #T_f365b_row40_col2, #T_f365b_row40_col3, #T_f365b_row40_col4, #T_f365b_row41_col0, #T_f365b_row41_col1, #T_f365b_row41_col2, #T_f365b_row41_col3, #T_f365b_row41_col4, #T_f365b_row43_col4, #T_f365b_row45_col0, #T_f365b_row45_col1, #T_f365b_row46_col4, #T_f365b_row47_col0, #T_f365b_row47_col1, #T_f365b_row47_col2, #T_f365b_row47_col3, #T_f365b_row47_col4, #T_f365b_row48_col0, #T_f365b_row48_col1, #T_f365b_row48_col2, #T_f365b_row48_col3, #T_f365b_row48_col4, #T_f365b_row49_col0, #T_f365b_row49_col1, #T_f365b_row49_col2, #T_f365b_row49_col3, #T_f365b_row49_col4, #T_f365b_row50_col0, #T_f365b_row50_col1, #T_f365b_row50_col2, #T_f365b_row50_col3, #T_f365b_row50_col4, #T_f365b_row51_col0, #T_f365b_row51_col1, #T_f365b_row51_col2, #T_f365b_row51_col3, #T_f365b_row51_col4, #T_f365b_row52_col0, #T_f365b_row52_col1, #T_f365b_row52_col2, #T_f365b_row52_col3, #T_f365b_row52_col4, #T_f365b_row53_col0, #T_f365b_row53_col1, #T_f365b_row53_col2, #T_f365b_row53_col3, #T_f365b_row53_col4, #T_f365b_row55_col0, #T_f365b_row55_col1, #T_f365b_row55_col2, #T_f365b_row55_col3, #T_f365b_row55_col4, #T_f365b_row56_col0, #T_f365b_row57_col0, #T_f365b_row57_col1, #T_f365b_row57_col2, #T_f365b_row57_col3, #T_f365b_row57_col4, #T_f365b_row59_col0, #T_f365b_row59_col1, #T_f365b_row59_col4, #T_f365b_row63_col0, #T_f365b_row63_col1, #T_f365b_row63_col2, #T_f365b_row63_col4, #T_f365b_row64_col0, #T_f365b_row64_col ...
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_f365b_row2_col0 {
#   background-color: #17934e;
#   color: #f1f1f1;
# }
# #T_f365b_row2_col1, #T_f365b_row44_col1 {
#   background-color: #51b35e;
#   color: #f1f1f1;
# }
# #T_f365b_row2_col2, #T_f365b_row3_col0, #T_f365b_row39_col0, #T_f365b_row72_col2, #T_f365b_row82_col0, #T_f365b_row82_col1, #T_f365b_row82_col3 {
#   background-color: #b7e075;
#   color: #000000;
# }
# #T_f365b_row2_col3, #T_f365b_row22_col2 {
#   background-color: #cbe982;
#   color: #000000;
# }
# #T_f365b_row2_col4, #T_f365b_row38_col4, #T_f365b_row42_col4, #T_f365b_row44_col4 {
#   background-color: #06733d;
#   color: #f1f1f1;
# }
# #T_f365b_row3_col1, #T_f365b_row39_col2 {
#   background-color: #fdbf6f;
#   color: #000000;
# }
# #T_f365b_row4_col0 {
#   background-color: #1b9950;
#   color: #f1f1f1;
# }
# #T_f365b_row4_col1, #T_f365b_row12_col0 {
#   background-color: #138c4a;
#   color: #f1f1f1;
# }
# #T_f365b_row4_col2, #T_f365b_row12_col2 {
#   background-color: #f1f9ac;
#   color: #000000;
# }
# #T_f365b_row4_col3 {
#   background-color: #c3e67d;
#   color: #000000;
# }
# #T_f365b_row5_col0, #T_f365b_row5_col1, #T_f365b_row5_col3, #T_f365b_row11_col1, #T_f365b_row23_col3, #T_f365b_row34_col3, #T_f365b_row43_col0, #T_f365b_row43_col1, #T_f365b_row43_col2, #T_f365b_row45_col2, #T_f365b_row46_col1 {
#   background-color: #66bd63;
#   color: #f1f1f1;
# }
# #T_f365b_row5_col2, #T_f365b_row23_col1, #T_f365b_row23_col2, #T_f365b_row43_col3, #T_f365b_row45_col3, #T_f365b_row45_col4, #T_f365b_row46_col2, #T_f365b_row61_col2 {
#   background-color: #d9ef8b;
#   color: #000000;
# }
# #T_f365b_row6_col0, #T_f365b_row6_col1, #T_f365b_row6_col2, #T_f365b_row58_col3, #T_f365b_row77_col3, #T_f365b_row80_col0, #T_f365b_row80_col3 {
#   background-color: #87cb67;
#   color: #000000;
# }
# #T_f365b_row6_col3, #T_f365b_row6_col4, #T_f365b_row44_col3, #T_f365b_row58_col0 {
#   background-color: #2da155;
#   color: #f1f1f1;
# }
# #T_f365b_row7_col2, #T_f365b_row25_col1, #T_f365b_row63_col3, #T_f365b_row64_col2, #T_f365b_row83_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_f365b_row10_col0, #T_f365b_row10_col3 {
