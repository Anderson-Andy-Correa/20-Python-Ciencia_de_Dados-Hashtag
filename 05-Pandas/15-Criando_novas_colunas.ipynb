# %% [markdown]
# # Pandas básico

# %%
import pandas as pd

BASE = r"./dados/cereal_sem_negativos.csv"

df = pd.read_csv(BASE)

df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4    Apple Cinnamon Cheerios   G    C       110        2    2     180    1.5
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   10.5      10      70        25      1     1.0  0.75  29.509541

# %%
if not "total_carb" in df.columns:
    # df["total_carb"] = df["carbo"] + df["sugars"]
    # Insert total carb before the existing column carb
    df.insert(df.columns.get_loc("carbo"), "total_carb", df["carbo"] + df["sugars"])
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4    Apple Cinnamon Cheerios   G    C       110        2    2     180    1.5
#
#    total_carb  carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0        11.0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1        16.0    8.0       8     135         0      3     1.0  1.00  33.983679
# 2        12.0    7.0       5     320        25      3     1.0  0.33  59.425505
# 3         8.0    8.0       0     330        25      3     1.0  0.50  93.704912
# 4        20.5   10.5      10      70        25      1     1.0  0.75  29.509541

# %%
if not "weight_grams" in df.columns:
    df.insert(df.columns.get_loc("weight") + 1, "weight_grams", df["weight"] * 28.3495)

df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4    Apple Cinnamon Cheerios   G    C       110        2    2     180    1.5
#
#    total_carb  carbo  sugars  potass  vitamins  shelf  weight  weight_grams  \
# 0        11.0    5.0       6     280        25      3     1.0       28.3495
# 1        16.0    8.0       8     135         0      3     1.0       28.3495
# 2        12.0    7.0       5     320        25      3     1.0       28.3495
# 3         8.0    8.0       0     330        25      3     1.0       28.3495
# 4        20.5   10.5      10      70        25      1     1.0       28.3495
#
#    cups     rating
# 0  0.33  68.402973
# ...

# %%
with pd.option_context("float_format", "{:.2f}".format):
    display(df.describe())
# Out:
#        calories  protein   fat  sodium  fiber  total_carb  carbo  sugars  \
# count     74.00    74.00 74.00   74.00  74.00       74.00  74.00   74.00
# mean     107.03     2.51  1.00  162.36   2.18       21.84  14.73    7.11
# std       19.84     1.08  1.01   82.77   2.42        4.34   3.89    4.36
# min       50.00     1.00  0.00    0.00   0.00        8.00   5.00    0.00
# 25%      100.00     2.00  0.00  135.00   0.25       20.00  12.00    3.00
# 50%      110.00     2.50  1.00  180.00   2.00       23.00  14.50    7.00
# 75%      110.00     3.00  1.00  217.50   3.00       25.00  17.00   11.00
# max      160.00     6.00  5.00  320.00  14.00       30.00  23.00   15.00
#
#        potass  vitamins  shelf  weight  weight_grams  cups  rating
# count   74.00     74.00  74.00   74.00         74.00 74.00   74.00
# mean    98.51     29.05   2.22    1.03         29.22  0.82   42.37
# std     70.88     22.29   0.83    0.15          4.35  0.24   14.03
# ...
